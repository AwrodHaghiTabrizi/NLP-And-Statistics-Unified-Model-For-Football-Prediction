# %%
import pandas as pd
import time
import json
import textwrap

# %% [markdown]
# #### Load dataset

# %%
dataset_dir = "../../../source/processed/Guardian_Kaggle_Combined_Dataset.csv"
df = pd.read_csv(dataset_dir)

# %% [markdown]
# #### Helper methods

# %%
def get_match_info(match_df_idx):
    return {
        "Match_ID": df.iloc[match_df_idx]['MatchID'],
        "Home": df.iloc[match_df_idx]['Home'],
        "Away": df.iloc[match_df_idx]['Away'],
        "Preview": df.iloc[match_df_idx]['Text'],
        "Season": df.iloc[match_df_idx]['Season'],
    }

# %%
def get_time():
    return time.strftime('%H:%M:%S')

# %% [markdown]
# #### Prompts

# %%
def create_prompt(match_df_idx, version=1):

    match_info = get_match_info(match_df_idx)
    home = match_info['Home']
    away = match_info['Away']
    preview = match_info['Preview']
    
    prompt = ""

    if version == 1:
        prompt += "You are tasked with reading a preview for a football match and determining based on the preview which team is being favored to win."
        prompt += f"Respond with the number based on the following scale that best matches the sentiment of the preview."
        prompt += f"If the home team is strongly favored to win, respond with 1."
        prompt += f"If the home team is slightly favored to win, respond with 2."
        prompt += f"If the match is balanced with no clear favor, respond with 3."
        prompt += f"If the away team is slightly favored to win, respond with 4."
        prompt += f"If the away team is strongly favored to win, respond with 5."
        prompt += f"The home team is {home} and the away team is {away}."
        prompt += f"The preview is: {preview}"

    elif version == 2:
        prompt += f"Is the home team {home} or the away team {away} favored to win the match based on the preview? "
        prompt += f"Use the underlying sentiment of the preview and understanding of football language and context. "
        prompt += f"If the home team {home} is strongly favored, respond '1'. "
        prompt += f"If the home team {home} is slightly favored, respond '2'. "
        prompt += f"If the match is balanced with no clear favorite, respond '3'. "
        prompt += f"If the away team {away} is slightly favored, respond '4'. "
        prompt += f"If the away team {away} is strongly favored, respond '5'. "
        prompt += f"Match preview: {preview}"
    
    elif version == 3:
        prompt += f"You are tasked with identifying if the home team {home} or the away team {away} is favored to win based on the match preview. "
        prompt += f"Do not use any historical performances or statistics to make your decision. "
        prompt += f"Just analyze the underlying sentiment of the preview and use understanding of football language and context. "
        prompt += f"If the home team {home} is strongly favored, respond '1'. "
        prompt += f"If the home team {home} is slightly favored, respond '2'. "
        prompt += f"If the match is balanced with no clear favorite, respond '3'. "
        prompt += f"If the away team {away} is slightly favored, respond '4'. "
        prompt += f"If the away team {away} is strongly favored, respond '5'. "
        prompt += f"Only respond with the number based on the scale that best matches the sentiment of the preview. "
        prompt += f"Although you should understand why you chose that number, you don't need to explain why. "
        prompt += f"Match preview: {preview}"
    
    return prompt

# %% [markdown]
# #### OpenAI

# %%
from openai import OpenAI

# %%
openai_api_key_dir = f"../../../../../API Keys/openai.txt"
with open(openai_api_key_dir) as f:
    lines = f.readlines()
    openai_api_key = lines[0].strip()

# %%
client = OpenAI(api_key=openai_api_key)

# %%
def get_openai_response(prompt, model="gpt-4o-mini", preliminary_content_version=1):

    if preliminary_content_version == 1:
        preliminary_content = "You are an AI assistant that analyzes and classifies sentiment in match previews for predicting match outcomes for the Premier League."
    else:
        preliminary_content = "You are an AI assistant that analyzes and classifies sentiment in match previews for predicting match outcomes for the Premier League."

    completion = client.chat.completions.create(
        model=model,
        messages=[
            {"role": "system", "content": preliminary_content},
            {"role": "user", "content": prompt}
        ]
    )

    return completion.choices[0].message.content

# %%
NUM_MODEL_SAMPLES = 5
MAX_ALLOWED_ATTEMPTS = 8

# Initialize model output json
model_output_dir = f"../model_output/sentiment-analysis_gpt-4o-mini_prompt-v3.json"
with open(model_output_dir, 'r') as f:
    model_output_json = json.load(f)

# Loop through each match
for match_df_idx in range(len(df)):

    # Get match information
    match_info = get_match_info(match_df_idx)
    match_id = match_info['Match_ID']
    match_id_str = str(match_id)
    home = match_info['Home']
    away = match_info['Away']
    season = match_info['Season']
    print(f"[{get_time()}] [Match ID {match_id}] Starting sentiment analysis for match ~ {home} vs {away}.")
    
    # Add match to model output json
    if match_id_str not in model_output_json:
        model_output_json[match_id_str] = []
    
    # Loop to get 5 responses
    attempts = 0
    while len(model_output_json[match_id_str]) < NUM_MODEL_SAMPLES:

        # Break early if too many attempts
        attempts += 1
        if attempts > MAX_ALLOWED_ATTEMPTS:
            print(f"[{get_time()}] [Match ID {match_id}] Max attempts ({attempts-1}) reached.")
            break

        # Get model output
        try:
            print(f"[{get_time()}] [Match ID {match_id}] Trying request attempt {attempts}.")
            prompt = create_prompt(match_df_idx, version=3)
            output = get_openai_response(prompt)
            output = output.strip()

            if len(output) > 1:
                print(f"[{get_time()}] [Match ID {match_id}] Issue with model output, longer than 1 character. ~ Output:\n{textwrap.fill(output, width=100)}")
                continue

            elif not(any(char in output for char in '12345')):
                print(f"[{get_time()}] [Match ID {match_id}] Issue with model output, No classification found in output. ~ Output:\n{textwrap.fill(output, width=100)}")
                continue

            # Add output to model output json
            model_output_json[match_id_str].append(output)
            with open(model_output_dir, 'w') as f:
                json.dump(model_output_json, f, indent=4)
            print(f"[{get_time()}] [Match ID {match_id}] Successfully recieved responce {len(model_output_json[match_id_str])}.")
        
        except Exception as e:
            print(f"[{get_time()}] [Match ID {match_id}] Error getting model output: {e}")

    print(f"\n[{get_time()}] [Match ID {match_id}] model_output_json[{match_id}]: {model_output_json[match_id_str]}\n")

print("\nFINAL RESULTS:")
for match_id_str in model_output_json:
    print(f"Match {match_id_str} output: {model_output_json[match_id_str]}")
# Out:
# [22:14:00] [Match ID 0] Starting sentiment analysis for match ~ Swansea City vs Stoke City.
#
# [22:14:00] [Match ID 0] model_output_json[0]: ['3', '3', '3', '3', '3']
#
# [22:14:00] [Match ID 2] Starting sentiment analysis for match ~ Tottenham Hotspur vs Leicester City.
#
# [22:14:00] [Match ID 2] model_output_json[2]: ['3', '3', '3', '2', '3']
#
# [22:14:00] [Match ID 3] Starting sentiment analysis for match ~ Liverpool vs Brighton & Hove Albion.
#
# [22:14:00] [Match ID 3] model_output_json[3]: ['1', '1', '1', '2', '2']
#
# [22:14:00] [Match ID 4] Starting sentiment analysis for match ~ Burnley vs AFC Bournemouth.
#
# [22:14:00] [Match ID 4] model_output_json[4]: ['3', '3', '3', '3', '3']
#
# [22:14:00] [Match ID 5] Starting sentiment analysis for match ~ Southampton vs Manchester City.
#
# [22:14:00] [Match ID 5] model_output_json[5]: ['5', '5', '5', '5', '5']
#
# [22:14:00] [Match ID 6] Starting sentiment analysis for match ~ Manchester United vs Watford.
#
# [22:14:00] [Match ID 6] model_output_json[6]: ['3', '3', '3', '3', '3']
#
# [22:14:00] [Match ID 7] Starting sentiment analysis for match ~ Crystal Palace vs West Bromwich Albion.
#
# [22:14:00] [Match ID 7] model_output_json[7]: ['3', '3', '3', '3', '3']
#
# [22:14:00] [Match ID 8] Starting sentiment analysis for match ~ West Ham United vs Everton.
#
# [22:14:00] [Match ID 8] model_output_json[8]: ['3', '3', '3', '3', '3']
#
# [22:14:00] [Match ID 9] Starting sentiment analysis for match ~ Arsenal vs Burnley.
#
# [22:14:00] [Match ID 9] model_output_json[9]: ['1', '2', '2', '2', '1']
#
# [22:14:00] [Match ID 10] Starting sentiment analysis for match ~ Chelsea vs Liverpool.
#
# [22:14:00] [Match ID 10] model_output_json[10]: ['3', '3', '3', '3', '3']
#
# [22:14:00] [Match ID 11] Starting sentiment analysis for match ~ Manchester City vs Huddersfield Town.
#
# [22:14:00] [Match ID 11] model_output_json[11]: ['1', '1', '1', '1', '1']
#
# [22:14:00] [Match ID 12] Starting sentiment analysis for match ~ Stoke City vs Crystal Palace.
#
# [22:14:00] [Match ID 12] model_output_json[12]: ['4', '4', '4', '4', '4']
#
# [22:14:00] [Match ID 13] Starting sentiment analysis for match ~ West Bromwich Albion vs Tottenham Hotspur.
#
# [22:14:00] [Match ID 13] model_output_json[13]: ['5', '5', '5', '5', '5']
#
# [22:14:00] [Match ID 15] Starting sentiment analysis for match ~ Leicester City vs West Ham United.
#
# [22:14:00] [Match ID 15] model_output_json[15]: ['5', '5', '5', '5', '5']
#
# [22:14:00] [Match ID 16] Starting sentiment analysis for match ~ AFC Bournemouth vs Swansea City.
#
# [22:14:00] [Match ID 16] model_output_json[16]: ['1', '1', '1', '1', '1']
#
# [22:14:00] [Match ID 17] Starting sentiment analysis for match ~ Everton vs Southampton.
#
# [22:14:00] [Match ID 17] model_output_json[17]: ['3', '3', '3', '3', '3']
#
# [22:14:00] [Match ID 18] Starting sentiment analysis for match ~ Tottenham Hotspur vs Watford.
#
# [22:14:00] [Match ID 18] model_output_json[18]: ['1', '2', '1', '2', '1']
#
# [22:14:00] [Match ID 19] Starting sentiment analysis for match ~ West Ham United vs Manchester City.
#
# [22:14:00] [Match ID 19] model_output_json[19]: ['5', '5', '5', '5', '5']
#
# [22:14:00] [Match ID 20] Starting sentiment analysis for match ~ Manchester United vs Arsenal.
#
# [22:14:00] [Match ID 20] model_output_json[20]: ['3', '3', '3', '3', '3']
#
# [22:14:00] [Match ID 21] Starting sentiment analysis for match ~ Burnley vs Brighton & Hove Albion.
#
# [22:14:00] [Match ID 21] model_output_json[21]: ['2', '2', '2', '2', '2']
#
# [22:14:00] [Match ID 23] Starting sentiment analysis for match ~ Swansea City vs Chelsea.
#
# [22:14:00] [Match ID 23] model_output_json[23]: ['4', '4', '4', '4', '4']
#
# [22:14:00] [Match ID 24] Starting sentiment analysis for match ~ Crystal Palace vs Leicester City.
#
# [22:14:00] [Match ID 24] model_output_json[24]: ['2', '1', '2', '2', '2']
#
# [22:14:00] [Match ID 25] Starting sentiment analysis for match ~ Huddersfield Town vs Everton.
#
# [22:14:00] [Match ID 25] model_output_json[25]: ['5', '5', '4', '5', '5']
#
# [22:14:00] [Match ID 26] Starting sentiment analysis for match ~ Southampton vs AFC Bournemouth.
#
# [22:14:00] [Match ID 26] model_output_json[26]: ['3', '3', '3', '4', '3']
#
# [22:14:00] [Match ID 27] Starting sentiment analysis for match ~ Liverpool vs Stoke City.
#
# [22:14:00] [Match ID 27] model_output_json[27]: ['1', '1', '1', '1', '1']
#
# [22:14:00] [Match ID 28] Starting sentiment analysis for match ~ Everton vs Newcastle.
#
# [22:14:00] [Match ID 28] model_output_json[28]: ['5', '5', '5', '5', '5']
#
# [22:14:00] [Match ID 29] Starting sentiment analysis for match ~ Arsenal vs West Ham United.
#
# [22:14:00] [Match ID 29] model_output_json[29]: ['3', '3', '2', '3', '3']
#
# [22:14:00] [Match ID 30] Starting sentiment analysis for match ~ Chelsea vs Southampton.
#
# [22:14:00] [Match ID 30] model_output_json[30]: ['1', '1', '1', '1', '1']
#
# [22:14:00] [Match ID 31] Starting sentiment analysis for match ~ Manchester City vs Swansea City.
#
# [22:14:00] [Match ID 31] model_output_json[31]: ['1', '1', '1', '1', '1']
#
# [22:14:00] [Match ID 32] Starting sentiment analysis for match ~ Stoke City vs Burnley.
#
# [22:14:00] [Match ID 32] model_output_json[32]: ['4', '3', '4', '4', '3']
#
# [22:14:00] [Match ID 33] Starting sentiment analysis for match ~ Manchester United vs Tottenham Hotspur.
#
# [22:14:00] [Match ID 33] model_output_json[33]: ['3', '3', '3', '3', '3']
#
# [22:14:00] [Match ID 34] Starting sentiment analysis for match ~ West Bromwich Albion vs Liverpool.
#
# [22:14:00] [Match ID 34] model_output_json[34]: ['5', '5', '5', '5', '5']
#
# [22:14:00] [Match ID 35] Starting sentiment analysis for match ~ Watford vs Crystal Palace.
#
# [22:14:00] [Match ID 35] model_output_json[35]: ['5', '5', '5', '5', '5']
#
# [22:14:00] [Match ID 36] Starting sentiment analysis for match ~ West Ham United vs Stoke City.
#
# [22:14:00] [Match ID 36] model_output_json[36]: ['3', '3', '3', '3', '3']
#
# [22:14:00] [Match ID 38] Starting sentiment analysis for match ~ Manchester United vs West Bromwich Albion.
#
# [22:14:00] [Match ID 38] model_output_json[38]: ['1', '1', '1', '1', '1']
#
# [22:14:00] [Match ID 39] Starting sentiment analysis for match ~ Huddersfield Town vs Watford.
#
# [22:14:00] [Match ID 39] model_output_json[39]: ['3', '3', '4', '3', '3']
#
# [22:14:00] [Match ID 40] Starting sentiment analysis for match ~ Swansea City vs Everton.
#
# [22:14:00] [Match ID 40] model_output_json[40]: ['2', '1', '2', '2', '2']
#
# [22:14:00] [Match ID 41] Starting sentiment analysis for match ~ Tottenham Hotspur vs Manchester City.
#
# [22:14:00] [Match ID 41] model_output_json[41]: ['4', '4', '3', '4', '4']
#
# [22:14:00] [Match ID 42] Starting sentiment analysis for match ~ Southampton vs Chelsea.
#
# [22:14:00] [Match ID 42] model_output_json[42]: ['4', '4', '4', '4', '3']
#
# [22:14:00] [Match ID 43] Starting sentiment analysis for match ~ Burnley vs Leicester City.
#
# [22:14:00] [Match ID 43] model_output_json[43]: ['2', '2', '2', '2', '2']
#
# [22:14:00] [Match ID 44] Starting sentiment analysis for match ~ Liverpool vs AFC Bournemouth.
#
# [22:14:00] [Match ID 44] model_output_json[44]: ['2', '2', '2', '2', '2']
#
# [22:14:00] [Match ID 45] Starting sentiment analysis for match ~ Crystal Palace vs Brighton & Hove Albion.
#
# [22:14:00] [Match ID 45] model_output_json[45]: ['4', '3', '4', '4', '3']
#
# [22:14:00] [Match ID 46] Starting sentiment analysis for match ~ Arsenal vs Southampton.
#
# [22:14:00] [Match ID 46] model_output_json[46]: ['1', '1', '1', '1', '1']
#
# [22:14:00] [Match ID 47] Starting sentiment analysis for match ~ Chelsea vs West Ham United.
#
# [22:14:00] [Match ID 47] model_output_json[47]: ['3', '3', '3', '3', '3']
#
# [22:14:00] [Match ID 48] Starting sentiment analysis for match ~ Watford vs Burnley.
#
# [22:14:00] [Match ID 48] model_output_json[48]: ['5', '5', '5', '5', '5']
#
# [22:14:00] [Match ID 49] Starting sentiment analysis for match ~ Brighton & Hove Albion vs Huddersfield Town.
#
# [22:14:00] [Match ID 49] model_output_json[49]: ['3', '3', '3', '3', '3']
#
# [22:14:00] [Match ID 50] Starting sentiment analysis for match ~ Manchester City vs Manchester United.
#
# [22:14:00] [Match ID 50] model_output_json[50]: ['1', '1', '1', '1', '1']
#
# [22:14:00] [Match ID 52] Starting sentiment analysis for match ~ West Bromwich Albion vs Swansea City.
#
# [22:14:00] [Match ID 52] model_output_json[52]: ['4', '4', '4', '4', '4']
#
# [22:14:00] [Match ID 53] Starting sentiment analysis for match ~ Everton vs Liverpool.
#
# [22:14:00] [Match ID 53] model_output_json[53]: ['5', '5', '5', '5', '5']
#
# [22:14:00] [Match ID 54] Starting sentiment analysis for match ~ Stoke City vs Tottenham Hotspur.
#
# [22:14:00] [Match ID 54] model_output_json[54]: ['5', '5', '5', '5', '5']
#
# [22:14:00] [Match ID 55] Starting sentiment analysis for match ~ AFC Bournemouth vs Crystal Palace.
# [22:14:00] [Match ID 55] Trying request attempt 1.
# [22:14:00] [Match ID 55] Successfully recieved responce 1.
# [22:14:00] [Match ID 55] Trying request attempt 2.
# [22:14:01] [Match ID 55] Successfully recieved responce 2.
# [22:14:01] [Match ID 55] Trying request attempt 3.
# [22:14:01] [Match ID 55] Successfully recieved responce 3.
# [22:14:01] [Match ID 55] Trying request attempt 4.
# [22:14:01] [Match ID 55] Successfully recieved responce 4.
# [22:14:01] [Match ID 55] Trying request attempt 5.
# [22:14:02] [Match ID 55] Successfully recieved responce 5.
#
# [22:14:02] [Match ID 55] model_output_json[55]: ['3', '4', '3', '4', '3']
#
# [22:14:02] [Match ID 56] Starting sentiment analysis for match ~ Chelsea vs Tottenham Hotspur.
# [22:14:02] [Match ID 56] Trying request attempt 1.
# [22:14:02] [Match ID 56] Successfully recieved responce 1.
# [22:14:02] [Match ID 56] Trying request attempt 2.
# [22:14:03] [Match ID 56] Successfully recieved responce 2.
# [22:14:03] [Match ID 56] Trying request attempt 3.
# [22:14:03] [Match ID 56] Successfully recieved responce 3.
# [22:14:03] [Match ID 56] Trying request attempt 4.
# [22:14:03] [Match ID 56] Successfully recieved responce 4.
# [22:14:03] [Match ID 56] Trying request attempt 5.
# [22:14:04] [Match ID 56] Successfully recieved responce 5.
#
# [22:14:04] [Match ID 56] model_output_json[56]: ['4', '4', '3', '4', '4']
#
# [22:14:04] [Match ID 57] Starting sentiment analysis for match ~ Arsenal vs Stoke City.
# [22:14:04] [Match ID 57] Trying request attempt 1.
# [22:14:04] [Match ID 57] Successfully recieved responce 1.
# [22:14:04] [Match ID 57] Trying request attempt 2.
# [22:14:04] [Match ID 57] Successfully recieved responce 2.
# [22:14:04] [Match ID 57] Trying request attempt 3.
# [22:14:05] [Match ID 57] Successfully recieved responce 3.
# [22:14:05] [Match ID 57] Trying request attempt 4.
# [22:14:05] [Match ID 57] Successfully recieved responce 4.
# [22:14:05] [Match ID 57] Trying request attempt 5.
# [22:14:05] [Match ID 57] Successfully recieved responce 5.
#
# [22:14:05] [Match ID 57] model_output_json[57]: ['4', '4', '4', '4', '4']
#
# [22:14:05] [Match ID 59] Starting sentiment analysis for match ~ Everton vs Manchester City.
# [22:14:05] [Match ID 59] Trying request attempt 1.
# [22:14:05] [Match ID 59] Successfully recieved responce 1.
# [22:14:05] [Match ID 59] Trying request attempt 2.
# [22:14:06] [Match ID 59] Successfully recieved responce 2.
# [22:14:06] [Match ID 59] Trying request attempt 3.
# [22:14:06] [Match ID 59] Successfully recieved responce 3.
# [22:14:06] [Match ID 59] Trying request attempt 4.
# [22:14:06] [Match ID 59] Successfully recieved responce 4.
# [22:14:06] [Match ID 59] Trying request attempt 5.
# [22:14:06] [Match ID 59] Successfully recieved responce 5.
#
# [22:14:06] [Match ID 59] model_output_json[59]: ['4', '4', '4', '4', '4']
#
# [22:14:06] [Match ID 60] Starting sentiment analysis for match ~ Brighton & Hove Albion vs Leicester City.
# [22:14:06] [Match ID 60] Trying request attempt 1.
# [22:14:07] [Match ID 60] Successfully recieved responce 1.
# [22:14:07] [Match ID 60] Trying request attempt 2.
# [22:14:07] [Match ID 60] Successfully recieved responce 2.
# [22:14:07] [Match ID 60] Trying request attempt 3.
# [22:14:07] [Match ID 60] Successfully recieved responce 3.
# [22:14:07] [Match ID 60] Trying request attempt 4.
# [22:14:08] [Match ID 60] Successfully recieved responce 4.
# [22:14:08] [Match ID 60] Trying request attempt 5.
# [22:14:08] [Match ID 60] Successfully recieved responce 5.
#
# [22:14:08] [Match ID 60] model_output_json[60]: ['2', '2', '2', '2', '2']
#
# [22:14:08] [Match ID 61] Starting sentiment analysis for match ~ West Bromwich Albion vs Burnley.
# [22:14:08] [Match ID 61] Trying request attempt 1.
# [22:14:08] [Match ID 61] Successfully recieved responce 1.
# [22:14:08] [Match ID 61] Trying request attempt 2.
# [22:14:09] [Match ID 61] Successfully recieved responce 2.
# [22:14:09] [Match ID 61] Trying request attempt 3.
# [22:14:09] [Match ID 61] Successfully recieved responce 3.
# [22:14:09] [Match ID 61] Trying request attempt 4.
# [22:14:09] [Match ID 61] Successfully recieved responce 4.
# [22:14:09] [Match ID 61] Trying request attempt 5.
# [22:14:10] [Match ID 61] Successfully recieved responce 5.
#
# [22:14:10] [Match ID 61] model_output_json[61]: ['5', '5', '5', '5', '5']
#
# [22:14:10] [Match ID 62] Starting sentiment analysis for match ~ West Ham United vs Southampton.
# [22:14:10] [Match ID 62] Trying request attempt 1.
# [22:14:10] [Match ID 62] Successfully recieved responce 1.
# [22:14:10] [Match ID 62] Trying request attempt 2.
# [22:14:11] [Match ID 62] Successfully recieved responce 2.
# [22:14:11] [Match ID 62] Trying request attempt 3.
# [22:14:11] [Match ID 62] Successfully recieved responce 3.
# [22:14:11] [Match ID 62] Trying request attempt 4.
# [22:14:12] [Match ID 62] Successfully recieved responce 4.
# [22:14:12] [Match ID 62] Trying request attempt 5.
# [22:14:12] [Match ID 62] Successfully recieved responce 5.
#
# [22:14:12] [Match ID 62] model_output_json[62]: ['3', '3', '3', '3', '3']
#
# [22:14:12] [Match ID 63] Starting sentiment analysis for match ~ Manchester United vs Swansea City.
# [22:14:12] [Match ID 63] Trying request attempt 1.
# [22:14:13] [Match ID 63] Successfully recieved responce 1.
# [22:14:13] [Match ID 63] Trying request attempt 2.
# [22:14:13] [Match ID 63] Successfully recieved responce 2.
# [22:14:13] [Match ID 63] Trying request attempt 3.
# [22:14:13] [Match ID 63] Successfully recieved responce 3.
# [22:14:13] [Match ID 63] Trying request attempt 4.
# [22:14:14] [Match ID 63] Successfully recieved responce 4.
# [22:14:14] [Match ID 63] Trying request attempt 5.
# [22:14:14] [Match ID 63] Successfully recieved responce 5.
#
# [22:14:14] [Match ID 63] model_output_json[63]: ['2', '2', '2', '2', '2']
#
# [22:14:14] [Match ID 64] Starting sentiment analysis for match ~ Watford vs AFC Bournemouth.
# [22:14:14] [Match ID 64] Trying request attempt 1.
# [22:14:14] [Match ID 64] Successfully recieved responce 1.
# [22:14:14] [Match ID 64] Trying request attempt 2.
# [22:14:15] [Match ID 64] Successfully recieved responce 2.
# [22:14:15] [Match ID 64] Trying request attempt 3.
# [22:14:15] [Match ID 64] Successfully recieved responce 3.
# [22:14:15] [Match ID 64] Trying request attempt 4.
# [22:14:15] [Match ID 64] Successfully recieved responce 4.
# [22:14:15] [Match ID 64] Trying request attempt 5.
# [22:14:16] [Match ID 64] Successfully recieved responce 5.
#
# [22:14:16] [Match ID 64] model_output_json[64]: ['2', '2', '2', '2', '3']
#
# [22:14:16] [Match ID 65] Starting sentiment analysis for match ~ Crystal Palace vs Liverpool.
# [22:14:16] [Match ID 65] Trying request attempt 1.
# [22:14:16] [Match ID 65] Successfully recieved responce 1.
# [22:14:16] [Match ID 65] Trying request attempt 2.
# [22:14:16] [Match ID 65] Successfully recieved responce 2.
# [22:14:16] [Match ID 65] Trying request attempt 3.
# [22:14:16] [Match ID 65] Successfully recieved responce 3.
# [22:14:16] [Match ID 65] Trying request attempt 4.
# [22:14:17] [Match ID 65] Successfully recieved responce 4.
# [22:14:17] [Match ID 65] Trying request attempt 5.
# [22:14:17] [Match ID 65] Successfully recieved responce 5.
#
# [22:14:17] [Match ID 65] model_output_json[65]: ['4', '4', '4', '4', '4']
#
# [22:14:17] [Match ID 66] Starting sentiment analysis for match ~ Leicester City vs Chelsea.
# [22:14:17] [Match ID 66] Trying request attempt 1.
# [22:14:17] [Match ID 66] Successfully recieved responce 1.
# [22:14:17] [Match ID 66] Trying request attempt 2.
# [22:14:17] [Match ID 66] Successfully recieved responce 2.
# [22:14:17] [Match ID 66] Trying request attempt 3.
# [22:14:18] [Match ID 66] Successfully recieved responce 3.
# [22:14:18] [Match ID 66] Trying request attempt 4.
# [22:14:18] [Match ID 66] Successfully recieved responce 4.
# [22:14:18] [Match ID 66] Trying request attempt 5.
# [22:14:18] [Match ID 66] Successfully recieved responce 5.
#
# [22:14:18] [Match ID 66] model_output_json[66]: ['3', '2', '2', '2', '2']
#
# [22:14:18] [Match ID 68] Starting sentiment analysis for match ~ Huddersfield Town vs Crystal Palace.
# [22:14:18] [Match ID 68] Trying request attempt 1.
# [22:14:19] [Match ID 68] Successfully recieved responce 1.
# [22:14:19] [Match ID 68] Trying request attempt 2.
# [22:14:19] [Match ID 68] Successfully recieved responce 2.
# [22:14:19] [Match ID 68] Trying request attempt 3.
# [22:14:19] [Match ID 68] Successfully recieved responce 3.
# [22:14:19] [Match ID 68] Trying request attempt 4.
# [22:14:20] [Match ID 68] Successfully recieved responce 4.
# [22:14:20] [Match ID 68] Trying request attempt 5.
# [22:14:20] [Match ID 68] Successfully recieved responce 5.
#
# [22:14:20] [Match ID 68] model_output_json[68]: ['4', '4', '4', '4', '4']
#
# [22:14:20] [Match ID 69] Starting sentiment analysis for match ~ Stoke City vs Everton.
# [22:14:20] [Match ID 69] Trying request attempt 1.
# [22:14:20] [Match ID 69] Successfully recieved responce 1.
# [22:14:20] [Match ID 69] Trying request attempt 2.
# [22:14:20] [Match ID 69] Successfully recieved responce 2.
# [22:14:20] [Match ID 69] Trying request attempt 3.
# [22:14:21] [Match ID 69] Successfully recieved responce 3.
# [22:14:21] [Match ID 69] Trying request attempt 4.
# [22:14:21] [Match ID 69] Successfully recieved responce 4.
# [22:14:21] [Match ID 69] Trying request attempt 5.
# [22:14:21] [Match ID 69] Successfully recieved responce 5.
#
# [22:14:21] [Match ID 69] model_output_json[69]: ['2', '4', '2', '3', '2']
#
# [22:14:21] [Match ID 70] Starting sentiment analysis for match ~ Manchester United vs Brighton & Hove Albion.
# [22:14:21] [Match ID 70] Trying request attempt 1.
# [22:14:21] [Match ID 70] Successfully recieved responce 1.
# [22:14:21] [Match ID 70] Trying request attempt 2.
# [22:14:22] [Match ID 70] Successfully recieved responce 2.
# [22:14:22] [Match ID 70] Trying request attempt 3.
# [22:14:22] [Match ID 70] Successfully recieved responce 3.
# [22:14:22] [Match ID 70] Trying request attempt 4.
# [22:14:23] [Match ID 70] Successfully recieved responce 4.
# [22:14:23] [Match ID 70] Trying request attempt 5.
# [22:14:23] [Match ID 70] Successfully recieved responce 5.
#
# [22:14:23] [Match ID 70] model_output_json[70]: ['3', '3', '3', '3', '3']
#
# [22:14:23] [Match ID 71] Starting sentiment analysis for match ~ Swansea City vs Tottenham Hotspur.
# [22:14:23] [Match ID 71] Trying request attempt 1.
# [22:14:23] [Match ID 71] Successfully recieved responce 1.
# [22:14:23] [Match ID 71] Trying request attempt 2.
# [22:14:24] [Match ID 71] Successfully recieved responce 2.
# [22:14:24] [Match ID 71] Trying request attempt 3.
# [22:14:24] [Match ID 71] Successfully recieved responce 3.
# [22:14:24] [Match ID 71] Trying request attempt 4.
# [22:14:24] [Match ID 71] Successfully recieved responce 4.
# [22:14:24] [Match ID 71] Trying request attempt 5.
# [22:14:25] [Match ID 71] Successfully recieved responce 5.
#
# [22:14:25] [Match ID 71] model_output_json[71]: ['4', '4', '4', '4', '4']
#
# [22:14:25] [Match ID 72] Starting sentiment analysis for match ~ Liverpool vs Watford.
# [22:14:25] [Match ID 72] Trying request attempt 1.
# [22:14:25] [Match ID 72] Successfully recieved responce 1.
# [22:14:25] [Match ID 72] Trying request attempt 2.
# [22:14:25] [Match ID 72] Successfully recieved responce 2.
# [22:14:25] [Match ID 72] Trying request attempt 3.
# [22:14:25] [Match ID 72] Successfully recieved responce 3.
# [22:14:25] [Match ID 72] Trying request attempt 4.
# [22:14:26] [Match ID 72] Successfully recieved responce 4.
# [22:14:26] [Match ID 72] Trying request attempt 5.
# [22:14:26] [Match ID 72] Successfully recieved responce 5.
#
# [22:14:26] [Match ID 72] model_output_json[72]: ['1', '2', '2', '2', '2']
#
# [22:14:26] [Match ID 73] Starting sentiment analysis for match ~ AFC Bournemouth vs West Bromwich Albion.
# [22:14:26] [Match ID 73] Trying request attempt 1.
# [22:14:26] [Match ID 73] Successfully recieved responce 1.
# [22:14:26] [Match ID 73] Trying request attempt 2.
# [22:14:27] [Match ID 73] Successfully recieved responce 2.
# [22:14:27] [Match ID 73] Trying request attempt 3.
# [22:14:27] [Match ID 73] Successfully recieved responce 3.
# [22:14:27] [Match ID 73] Trying request attempt 4.
# [22:14:27] [Match ID 73] Successfully recieved responce 4.
# [22:14:27] [Match ID 73] Trying request attempt 5.
# [22:14:28] [Match ID 73] Successfully recieved responce 5.
#
# [22:14:28] [Match ID 73] model_output_json[73]: ['1', '1', '1', '1', '1']
#
# [22:14:28] [Match ID 74] Starting sentiment analysis for match ~ AFC Bournemouth vs Tottenham Hotspur.
# [22:14:28] [Match ID 74] Trying request attempt 1.
# [22:14:28] [Match ID 74] Successfully recieved responce 1.
# [22:14:28] [Match ID 74] Trying request attempt 2.
# [22:14:28] [Match ID 74] Successfully recieved responce 2.
# [22:14:28] [Match ID 74] Trying request attempt 3.
# [22:14:28] [Match ID 74] Successfully recieved responce 3.
# [22:14:28] [Match ID 74] Trying request attempt 4.
# [22:14:29] [Match ID 74] Successfully recieved responce 4.
# [22:14:29] [Match ID 74] Trying request attempt 5.
# [22:14:29] [Match ID 74] Successfully recieved responce 5.
#
# [22:14:29] [Match ID 74] model_output_json[74]: ['5', '5', '5', '5', '5']
#
# [22:14:29] [Match ID 75] Starting sentiment analysis for match ~ Stoke City vs Manchester City.
# [22:14:29] [Match ID 75] Trying request attempt 1.
# [22:14:29] [Match ID 75] Successfully recieved responce 1.
# [22:14:29] [Match ID 75] Trying request attempt 2.
# [22:14:30] [Match ID 75] Successfully recieved responce 2.
# [22:14:30] [Match ID 75] Trying request attempt 3.
# [22:14:32] [Match ID 75] Successfully recieved responce 3.
# [22:14:32] [Match ID 75] Trying request attempt 4.
# [22:14:32] [Match ID 75] Successfully recieved responce 4.
# [22:14:32] [Match ID 75] Trying request attempt 5.
# [22:14:33] [Match ID 75] Successfully recieved responce 5.
#
# [22:14:33] [Match ID 75] model_output_json[75]: ['4', '4', '4', '4', '4']
#
# [22:14:33] [Match ID 76] Starting sentiment analysis for match ~ Arsenal vs Watford.
# [22:14:33] [Match ID 76] Trying request attempt 1.
# [22:14:33] [Match ID 76] Successfully recieved responce 1.
# [22:14:33] [Match ID 76] Trying request attempt 2.
# [22:14:33] [Match ID 76] Successfully recieved responce 2.
# [22:14:33] [Match ID 76] Trying request attempt 3.
# [22:14:33] [Match ID 76] Successfully recieved responce 3.
# [22:14:33] [Match ID 76] Trying request attempt 4.
# [22:14:34] [Match ID 76] Successfully recieved responce 4.
# [22:14:34] [Match ID 76] Trying request attempt 5.
# [22:14:34] [Match ID 76] Successfully recieved responce 5.
#
# [22:14:34] [Match ID 76] model_output_json[76]: ['3', '2', '3', '3', '2']
#
# [22:14:34] [Match ID 77] Starting sentiment analysis for match ~ West Ham United vs Burnley.
# [22:14:34] [Match ID 77] Trying request attempt 1.
# [22:14:34] [Match ID 77] Successfully recieved responce 1.
# [22:14:34] [Match ID 77] Trying request attempt 2.
# [22:14:35] [Match ID 77] Successfully recieved responce 2.
# [22:14:35] [Match ID 77] Trying request attempt 3.
# [22:14:35] [Match ID 77] Successfully recieved responce 3.
# [22:14:35] [Match ID 77] Trying request attempt 4.
# [22:14:35] [Match ID 77] Successfully recieved responce 4.
# [22:14:35] [Match ID 77] Trying request attempt 5.
# [22:14:36] [Match ID 77] Successfully recieved responce 5.
#
# [22:14:36] [Match ID 77] model_output_json[77]: ['2', '2', '2', '2', '2']
#
# [22:14:36] [Match ID 80] Starting sentiment analysis for match ~ Chelsea vs Crystal Palace.
# [22:14:36] [Match ID 80] Trying request attempt 1.
# [22:14:36] [Match ID 80] Successfully recieved responce 1.
# [22:14:36] [Match ID 80] Trying request attempt 2.
# [22:14:37] [Match ID 80] Successfully recieved responce 2.
# [22:14:37] [Match ID 80] Trying request attempt 3.
# [22:14:37] [Match ID 80] Successfully recieved responce 3.
# [22:14:37] [Match ID 80] Trying request attempt 4.
# [22:14:37] [Match ID 80] Successfully recieved responce 4.
# [22:14:37] [Match ID 80] Trying request attempt 5.
# [22:14:37] [Match ID 80] Successfully recieved responce 5.
#
# [22:14:37] [Match ID 80] model_output_json[80]: ['4', '4', '4', '4', '4']
#
# [22:14:37] [Match ID 81] Starting sentiment analysis for match ~ Everton vs Brighton & Hove Albion.
# [22:14:37] [Match ID 81] Trying request attempt 1.
# [22:14:38] [Match ID 81] Successfully recieved responce 1.
# [22:14:38] [Match ID 81] Trying request attempt 2.
# [22:14:38] [Match ID 81] Successfully recieved responce 2.
# [22:14:38] [Match ID 81] Trying request attempt 3.
# [22:14:38] [Match ID 81] Successfully recieved responce 3.
# [22:14:38] [Match ID 81] Trying request attempt 4.
# [22:14:38] [Match ID 81] Successfully recieved responce 4.
# [22:14:38] [Match ID 81] Trying request attempt 5.
# [22:14:39] [Match ID 81] Successfully recieved responce 5.
#
# [22:14:39] [Match ID 81] model_output_json[81]: ['4', '4', '3', '4', '3']
#
# [22:14:39] [Match ID 82] Starting sentiment analysis for match ~ Huddersfield Town vs Swansea City.
# [22:14:39] [Match ID 82] Trying request attempt 1.
# [22:14:39] [Match ID 82] Successfully recieved responce 1.
# [22:14:39] [Match ID 82] Trying request attempt 2.
# [22:14:40] [Match ID 82] Successfully recieved responce 2.
# [22:14:40] [Match ID 82] Trying request attempt 3.
# [22:14:40] [Match ID 82] Successfully recieved responce 3.
# [22:14:40] [Match ID 82] Trying request attempt 4.
# [22:14:40] [Match ID 82] Successfully recieved responce 4.
# [22:14:40] [Match ID 82] Trying request attempt 5.
# [22:14:41] [Match ID 82] Successfully recieved responce 5.
#
# [22:14:41] [Match ID 82] model_output_json[82]: ['2', '2', '2', '2', '2']
#
# [22:14:41] [Match ID 83] Starting sentiment analysis for match ~ West Bromwich Albion vs Leicester City.
# [22:14:41] [Match ID 83] Trying request attempt 1.
# [22:14:42] [Match ID 83] Successfully recieved responce 1.
# [22:14:42] [Match ID 83] Trying request attempt 2.
# [22:14:42] [Match ID 83] Successfully recieved responce 2.
# [22:14:42] [Match ID 83] Trying request attempt 3.
# [22:14:42] [Match ID 83] Successfully recieved responce 3.
# [22:14:42] [Match ID 83] Trying request attempt 4.
# [22:14:42] [Match ID 83] Successfully recieved responce 4.
# [22:14:42] [Match ID 83] Trying request attempt 5.
# [22:14:43] [Match ID 83] Successfully recieved responce 5.
#
# [22:14:43] [Match ID 83] model_output_json[83]: ['5', '5', '5', '5', '5']
#
# [22:14:43] [Match ID 84] Starting sentiment analysis for match ~ Brighton & Hove Albion vs Arsenal.
# [22:14:43] [Match ID 84] Trying request attempt 1.
# [22:14:43] [Match ID 84] Successfully recieved responce 1.
# [22:14:43] [Match ID 84] Trying request attempt 2.
# [22:14:44] [Match ID 84] Successfully recieved responce 2.
# [22:14:44] [Match ID 84] Trying request attempt 3.
# [22:14:44] [Match ID 84] Successfully recieved responce 3.
# [22:14:44] [Match ID 84] Trying request attempt 4.
# [22:14:45] [Match ID 84] Successfully recieved responce 4.
# [22:14:45] [Match ID 84] Trying request attempt 5.
# [22:14:45] [Match ID 84] Successfully recieved responce 5.
#
# [22:14:45] [Match ID 84] model_output_json[84]: ['1', '1', '1', '1', '1']
#
# [22:14:45] [Match ID 85] Starting sentiment analysis for match ~ Manchester City vs Chelsea.
# [22:14:45] [Match ID 85] Trying request attempt 1.
# [22:14:45] [Match ID 85] Successfully recieved responce 1.
# [22:14:45] [Match ID 85] Trying request attempt 2.
# [22:14:46] [Match ID 85] Successfully recieved responce 2.
# [22:14:46] [Match ID 85] Trying request attempt 3.
# [22:14:46] [Match ID 85] Successfully recieved responce 3.
# [22:14:46] [Match ID 85] Trying request attempt 4.
# [22:14:46] [Match ID 85] Successfully recieved responce 4.
# [22:14:46] [Match ID 85] Trying request attempt 5.
# [22:14:46] [Match ID 85] Successfully recieved responce 5.
#
# [22:14:46] [Match ID 85] model_output_json[85]: ['1', '1', '1', '1', '1']
#
# [22:14:46] [Match ID 86] Starting sentiment analysis for match ~ Crystal Palace vs Manchester United.
# [22:14:46] [Match ID 86] Trying request attempt 1.
# [22:14:47] [Match ID 86] Successfully recieved responce 1.
# [22:14:47] [Match ID 86] Trying request attempt 2.
# [22:14:50] [Match ID 86] Successfully recieved responce 2.
# [22:14:50] [Match ID 86] Trying request attempt 3.
# [22:14:51] [Match ID 86] Successfully recieved responce 3.
# [22:14:51] [Match ID 86] Trying request attempt 4.
# [22:14:51] [Match ID 86] Successfully recieved responce 4.
# [22:14:51] [Match ID 86] Trying request attempt 5.
# [22:14:51] [Match ID 86] Successfully recieved responce 5.
#
# [22:14:51] [Match ID 86] model_output_json[86]: ['4', '4', '4', '4', '4']
#
# [22:14:51] [Match ID 87] Starting sentiment analysis for match ~ Southampton vs Stoke City.
# [22:14:51] [Match ID 87] Trying request attempt 1.
# [22:14:52] [Match ID 87] Successfully recieved responce 1.
# [22:14:52] [Match ID 87] Trying request attempt 2.
# [22:14:52] [Match ID 87] Successfully recieved responce 2.
# [22:14:52] [Match ID 87] Trying request attempt 3.
# [22:14:52] [Match ID 87] Successfully recieved responce 3.
# [22:14:52] [Match ID 87] Trying request attempt 4.
# [22:14:52] [Match ID 87] Successfully recieved responce 4.
# [22:14:52] [Match ID 87] Trying request attempt 5.
# [22:14:53] [Match ID 87] Successfully recieved responce 5.
#
# [22:14:53] [Match ID 87] model_output_json[87]: ['3', '3', '3', '3', '3']
#
# [22:14:53] [Match ID 88] Starting sentiment analysis for match ~ Tottenham Hotspur vs Huddersfield Town.
# [22:14:53] [Match ID 88] Trying request attempt 1.
# [22:14:53] [Match ID 88] Successfully recieved responce 1.
# [22:14:53] [Match ID 88] Trying request attempt 2.
# [22:14:54] [Match ID 88] Successfully recieved responce 2.
# [22:14:54] [Match ID 88] Trying request attempt 3.
# [22:14:54] [Match ID 88] Successfully recieved responce 3.
# [22:14:54] [Match ID 88] Trying request attempt 4.
# [22:14:54] [Match ID 88] Successfully recieved responce 4.
# [22:14:54] [Match ID 88] Trying request attempt 5.
# [22:14:54] [Match ID 88] Successfully recieved responce 5.
#
# [22:14:54] [Match ID 88] model_output_json[88]: ['2', '3', '3', '3', '2']
#
# [22:14:54] [Match ID 90] Starting sentiment analysis for match ~ Watford vs West Bromwich Albion.
# [22:14:54] [Match ID 90] Trying request attempt 1.
# [22:14:55] [Match ID 90] Successfully recieved responce 1.
# [22:14:55] [Match ID 90] Trying request attempt 2.
# [22:14:55] [Match ID 90] Successfully recieved responce 2.
# [22:14:55] [Match ID 90] Trying request attempt 3.
# [22:14:56] [Match ID 90] Successfully recieved responce 3.
# [22:14:56] [Match ID 90] Trying request attempt 4.
# [22:14:56] [Match ID 90] Successfully recieved responce 4.
# [22:14:56] [Match ID 90] Trying request attempt 5.
# [22:14:57] [Match ID 90] Successfully recieved responce 5.
#
# [22:14:57] [Match ID 90] model_output_json[90]: ['5', '4', '5', '5', '5']
#
# [22:14:57] [Match ID 91] Starting sentiment analysis for match ~ Swansea City vs West Ham United.
# [22:14:57] [Match ID 91] Trying request attempt 1.
# [22:14:57] [Match ID 91] Successfully recieved responce 1.
# [22:14:57] [Match ID 91] Trying request attempt 2.
# [22:14:58] [Match ID 91] Successfully recieved responce 2.
# [22:14:58] [Match ID 91] Trying request attempt 3.
# [22:14:58] [Match ID 91] Successfully recieved responce 3.
# [22:14:58] [Match ID 91] Trying request attempt 4.
# [22:14:58] [Match ID 91] Successfully recieved responce 4.
# [22:14:58] [Match ID 91] Trying request attempt 5.
# [22:14:59] [Match ID 91] Successfully recieved responce 5.
#
# [22:14:59] [Match ID 91] model_output_json[91]: ['2', '2', '3', '2', '2']
#
# [22:14:59] [Match ID 92] Starting sentiment analysis for match ~ Leicester City vs AFC Bournemouth.
# [22:14:59] [Match ID 92] Trying request attempt 1.
# [22:14:59] [Match ID 92] Successfully recieved responce 1.
# [22:14:59] [Match ID 92] Trying request attempt 2.
# [22:15:00] [Match ID 92] Successfully recieved responce 2.
# [22:15:00] [Match ID 92] Trying request attempt 3.
# [22:15:01] [Match ID 92] Successfully recieved responce 3.
# [22:15:01] [Match ID 92] Trying request attempt 4.
# [22:15:01] [Match ID 92] Successfully recieved responce 4.
# [22:15:01] [Match ID 92] Trying request attempt 5.
# [22:15:02] [Match ID 92] Successfully recieved responce 5.
#
# [22:15:02] [Match ID 92] model_output_json[92]: ['4', '3', '2', '3', '3']
#
# [22:15:02] [Match ID 93] Starting sentiment analysis for match ~ Burnley vs Everton.
# [22:15:02] [Match ID 93] Trying request attempt 1.
# [22:15:03] [Match ID 93] Successfully recieved responce 1.
# [22:15:03] [Match ID 93] Trying request attempt 2.
# [22:15:03] [Match ID 93] Successfully recieved responce 2.
# [22:15:03] [Match ID 93] Trying request attempt 3.
# [22:15:04] [Match ID 93] Successfully recieved responce 3.
# [22:15:04] [Match ID 93] Trying request attempt 4.
# [22:15:04] [Match ID 93] Successfully recieved responce 4.
# [22:15:04] [Match ID 93] Trying request attempt 5.
# [22:15:05] [Match ID 93] Successfully recieved responce 5.
#
# [22:15:05] [Match ID 93] model_output_json[93]: ['3', '3', '3', '3', '3']
#
# [22:15:05] [Match ID 94] Starting sentiment analysis for match ~ Manchester United vs Chelsea.
# [22:15:05] [Match ID 94] Trying request attempt 1.
# [22:15:05] [Match ID 94] Successfully recieved responce 1.
# [22:15:05] [Match ID 94] Trying request attempt 2.
# [22:15:05] [Match ID 94] Successfully recieved responce 2.
# [22:15:05] [Match ID 94] Trying request attempt 3.
# [22:15:06] [Match ID 94] Successfully recieved responce 3.
# [22:15:06] [Match ID 94] Trying request attempt 4.
# [22:15:06] [Match ID 94] Successfully recieved responce 4.
# [22:15:06] [Match ID 94] Trying request attempt 5.
# [22:15:06] [Match ID 94] Successfully recieved responce 5.
#
# [22:15:06] [Match ID 94] model_output_json[94]: ['3', '3', '3', '3', '3']
#
# [22:15:06] [Match ID 95] Starting sentiment analysis for match ~ Arsenal vs Manchester City.
# [22:15:06] [Match ID 95] Trying request attempt 1.
# [22:15:07] [Match ID 95] Successfully recieved responce 1.
# [22:15:07] [Match ID 95] Trying request attempt 2.
# [22:15:07] [Match ID 95] Successfully recieved responce 2.
# [22:15:07] [Match ID 95] Trying request attempt 3.
# [22:15:07] [Match ID 95] Successfully recieved responce 3.
# [22:15:07] [Match ID 95] Trying request attempt 4.
# [22:15:08] [Match ID 95] Successfully recieved responce 4.
# [22:15:08] [Match ID 95] Trying request attempt 5.
# [22:15:08] [Match ID 95] Successfully recieved responce 5.
#
# [22:15:08] [Match ID 95] model_output_json[95]: ['5', '5', '5', '5', '5']
#
# [22:15:08] [Match ID 96] Starting sentiment analysis for match ~ Crystal Palace vs Tottenham Hotspur.
# [22:15:08] [Match ID 96] Trying request attempt 1.
# [22:15:09] [Match ID 96] Successfully recieved responce 1.
# [22:15:09] [Match ID 96] Trying request attempt 2.
# [22:15:09] [Match ID 96] Successfully recieved responce 2.
# [22:15:09] [Match ID 96] Trying request attempt 3.
# [22:15:09] [Match ID 96] Successfully recieved responce 3.
# [22:15:09] [Match ID 96] Trying request attempt 4.
# [22:15:09] [Match ID 96] Successfully recieved responce 4.
# [22:15:09] [Match ID 96] Trying request attempt 5.
# [22:15:10] [Match ID 96] Successfully recieved responce 5.
#
# [22:15:10] [Match ID 96] model_output_json[96]: ['5', '5', '5', '5', '5']
#
# [22:15:10] [Match ID 97] Starting sentiment analysis for match ~ Watford vs Everton.
# [22:15:10] [Match ID 97] Trying request attempt 1.
# [22:15:10] [Match ID 97] Successfully recieved responce 1.
# [22:15:10] [Match ID 97] Trying request attempt 2.
# [22:15:11] [Match ID 97] Successfully recieved responce 2.
# [22:15:11] [Match ID 97] Trying request attempt 3.
# [22:15:11] [Match ID 97] Successfully recieved responce 3.
# [22:15:11] [Match ID 97] Trying request attempt 4.
# [22:15:12] [Match ID 97] Successfully recieved responce 4.
# [22:15:12] [Match ID 97] Trying request attempt 5.
# [22:15:12] [Match ID 97] Successfully recieved responce 5.
#
# [22:15:12] [Match ID 97] model_output_json[97]: ['3', '2', '2', '2', '2']
#
# [22:15:12] [Match ID 98] Starting sentiment analysis for match ~ Liverpool vs West Ham United.
# [22:15:12] [Match ID 98] Trying request attempt 1.
# [22:15:13] [Match ID 98] Successfully recieved responce 1.
# [22:15:13] [Match ID 98] Trying request attempt 2.
# [22:15:13] [Match ID 98] Successfully recieved responce 2.
# [22:15:13] [Match ID 98] Trying request attempt 3.
# [22:15:13] [Match ID 98] Successfully recieved responce 3.
# [22:15:13] [Match ID 98] Trying request attempt 4.
# [22:15:14] [Match ID 98] Successfully recieved responce 4.
# [22:15:14] [Match ID 98] Trying request attempt 5.
# [22:15:14] [Match ID 98] Successfully recieved responce 5.
#
# [22:15:14] [Match ID 98] model_output_json[98]: ['1', '1', '1', '1', '1']
#
# [22:15:14] [Match ID 100] Starting sentiment analysis for match ~ Brighton & Hove Albion vs Swansea City.
# [22:15:14] [Match ID 100] Trying request attempt 1.
# [22:15:14] [Match ID 100] Successfully recieved responce 1.
# [22:15:14] [Match ID 100] Trying request attempt 2.
# [22:15:15] [Match ID 100] Successfully recieved responce 2.
# [22:15:15] [Match ID 100] Trying request attempt 3.
# [22:15:15] [Match ID 100] Successfully recieved responce 3.
# [22:15:15] [Match ID 100] Trying request attempt 4.
# [22:15:15] [Match ID 100] Successfully recieved responce 4.
# [22:15:15] [Match ID 100] Trying request attempt 5.
# [22:15:15] [Match ID 100] Successfully recieved responce 5.
#
# [22:15:15] [Match ID 100] model_output_json[100]: ['3', '3', '3', '3', '3']
#
# [22:15:15] [Match ID 101] Starting sentiment analysis for match ~ Burnley vs Southampton.
# [22:15:15] [Match ID 101] Trying request attempt 1.
# [22:15:16] [Match ID 101] Successfully recieved responce 1.
# [22:15:16] [Match ID 101] Trying request attempt 2.
# [22:15:16] [Match ID 101] Successfully recieved responce 2.
# [22:15:16] [Match ID 101] Trying request attempt 3.
# [22:15:16] [Match ID 101] Successfully recieved responce 3.
# [22:15:16] [Match ID 101] Trying request attempt 4.
# [22:15:17] [Match ID 101] Successfully recieved responce 4.
# [22:15:17] [Match ID 101] Trying request attempt 5.
# [22:15:17] [Match ID 101] Successfully recieved responce 5.
#
# [22:15:17] [Match ID 101] model_output_json[101]: ['3', '3', '3', '3', '3']
#
# [22:15:17] [Match ID 102] Starting sentiment analysis for match ~ Leicester City vs Stoke City.
# [22:15:17] [Match ID 102] Trying request attempt 1.
# [22:15:17] [Match ID 102] Successfully recieved responce 1.
# [22:15:17] [Match ID 102] Trying request attempt 2.
# [22:15:17] [Match ID 102] Successfully recieved responce 2.
# [22:15:17] [Match ID 102] Trying request attempt 3.
# [22:15:18] [Match ID 102] Successfully recieved responce 3.
# [22:15:18] [Match ID 102] Trying request attempt 4.
# [22:15:18] [Match ID 102] Successfully recieved responce 4.
# [22:15:18] [Match ID 102] Trying request attempt 5.
# [22:15:18] [Match ID 102] Successfully recieved responce 5.
#
# [22:15:18] [Match ID 102] model_output_json[102]: ['4', '4', '3', '4', '4']
#
# [22:15:18] [Match ID 103] Starting sentiment analysis for match ~ West Bromwich Albion vs Huddersfield Town.
# [22:15:18] [Match ID 103] Trying request attempt 1.
# [22:15:19] [Match ID 103] Successfully recieved responce 1.
# [22:15:19] [Match ID 103] Trying request attempt 2.
# [22:15:19] [Match ID 103] Successfully recieved responce 2.
# [22:15:19] [Match ID 103] Trying request attempt 3.
# [22:15:20] [Match ID 103] Successfully recieved responce 3.
# [22:15:20] [Match ID 103] Trying request attempt 4.
# [22:15:20] [Match ID 103] Successfully recieved responce 4.
# [22:15:20] [Match ID 103] Trying request attempt 5.
# [22:15:21] [Match ID 103] Successfully recieved responce 5.
#
# [22:15:21] [Match ID 103] model_output_json[103]: ['3', '4', '4', '4', '4']
#
# [22:15:21] [Match ID 107] Starting sentiment analysis for match ~ West Bromwich Albion vs Southampton.
# [22:15:21] [Match ID 107] Trying request attempt 1.
# [22:15:21] [Match ID 107] Successfully recieved responce 1.
# [22:15:21] [Match ID 107] Trying request attempt 2.
# [22:15:21] [Match ID 107] Successfully recieved responce 2.
# [22:15:21] [Match ID 107] Trying request attempt 3.
# [22:15:21] [Match ID 107] Successfully recieved responce 3.
# [22:15:21] [Match ID 107] Trying request attempt 4.
# [22:15:22] [Match ID 107] Successfully recieved responce 4.
# [22:15:22] [Match ID 107] Trying request attempt 5.
# [22:15:22] [Match ID 107] Successfully recieved responce 5.
#
# [22:15:22] [Match ID 107] model_output_json[107]: ['4', '4', '4', '4', '4']
#
# [22:15:22] [Match ID 109] Starting sentiment analysis for match ~ Huddersfield Town vs Manchester United.
# [22:15:22] [Match ID 109] Trying request attempt 1.
# [22:15:23] [Match ID 109] Successfully recieved responce 1.
# [22:15:23] [Match ID 109] Trying request attempt 2.
# [22:15:23] [Match ID 109] Successfully recieved responce 2.
# [22:15:23] [Match ID 109] Trying request attempt 3.
# [22:15:24] [Match ID 109] Successfully recieved responce 3.
# [22:15:24] [Match ID 109] Trying request attempt 4.
# [22:15:24] [Match ID 109] Successfully recieved responce 4.
# [22:15:24] [Match ID 109] Trying request attempt 5.
# [22:15:24] [Match ID 109] Successfully recieved responce 5.
#
# [22:15:24] [Match ID 109] model_output_json[109]: ['4', '4', '4', '4', '4']
#
# [22:15:24] [Match ID 111] Starting sentiment analysis for match ~ Southampton vs Liverpool.
# [22:15:24] [Match ID 111] Trying request attempt 1.
# [22:15:25] [Match ID 111] Successfully recieved responce 1.
# [22:15:25] [Match ID 111] Trying request attempt 2.
# [22:15:25] [Match ID 111] Successfully recieved responce 2.
# [22:15:25] [Match ID 111] Trying request attempt 3.
# [22:15:25] [Match ID 111] Successfully recieved responce 3.
# [22:15:25] [Match ID 111] Trying request attempt 4.
# [22:15:26] [Match ID 111] Successfully recieved responce 4.
# [22:15:26] [Match ID 111] Trying request attempt 5.
# [22:15:26] [Match ID 111] Successfully recieved responce 5.
#
# [22:15:26] [Match ID 111] model_output_json[111]: ['5', '5', '4', '5', '5']
#
# [22:15:26] [Match ID 112] Starting sentiment analysis for match ~ Chelsea vs West Bromwich Albion.
# [22:15:26] [Match ID 112] Trying request attempt 1.
# [22:15:26] [Match ID 112] Successfully recieved responce 1.
# [22:15:26] [Match ID 112] Trying request attempt 2.
# [22:15:26] [Match ID 112] Successfully recieved responce 2.
# [22:15:26] [Match ID 112] Trying request attempt 3.
# [22:15:27] [Match ID 112] Successfully recieved responce 3.
# [22:15:27] [Match ID 112] Trying request attempt 4.
# [22:15:27] [Match ID 112] Successfully recieved responce 4.
# [22:15:27] [Match ID 112] Trying request attempt 5.
# [22:15:27] [Match ID 112] Successfully recieved responce 5.
#
# [22:15:27] [Match ID 112] model_output_json[112]: ['3', '3', '3', '3', '3']
#
# [22:15:27] [Match ID 113] Starting sentiment analysis for match ~ Huddersfield Town vs AFC Bournemouth.
# [22:15:27] [Match ID 113] Trying request attempt 1.
# [22:15:28] [Match ID 113] Successfully recieved responce 1.
# [22:15:28] [Match ID 113] Trying request attempt 2.
# [22:15:28] [Match ID 113] Successfully recieved responce 2.
# [22:15:28] [Match ID 113] Trying request attempt 3.
# [22:15:28] [Match ID 113] Successfully recieved responce 3.
# [22:15:28] [Match ID 113] Trying request attempt 4.
# [22:15:29] [Match ID 113] Successfully recieved responce 4.
# [22:15:29] [Match ID 113] Trying request attempt 5.
# [22:15:29] [Match ID 113] Successfully recieved responce 5.
#
# [22:15:29] [Match ID 113] model_output_json[113]: ['3', '3', '4', '3', '3']
#
# [22:15:29] [Match ID 114] Starting sentiment analysis for match ~ Swansea City vs Burnley.
# [22:15:29] [Match ID 114] Trying request attempt 1.
# [22:15:29] [Match ID 114] Successfully recieved responce 1.
# [22:15:29] [Match ID 114] Trying request attempt 2.
# [22:15:30] [Match ID 114] Successfully recieved responce 2.
# [22:15:30] [Match ID 114] Trying request attempt 3.
# [22:15:30] [Match ID 114] Successfully recieved responce 3.
# [22:15:30] [Match ID 114] Trying request attempt 4.
# [22:15:30] [Match ID 114] Successfully recieved responce 4.
# [22:15:30] [Match ID 114] Trying request attempt 5.
# [22:15:30] [Match ID 114] Successfully recieved responce 5.
#
# [22:15:30] [Match ID 114] model_output_json[114]: ['2', '2', '2', '2', '2']
#
# [22:15:30] [Match ID 115] Starting sentiment analysis for match ~ Manchester City vs Leicester City.
# [22:15:30] [Match ID 115] Trying request attempt 1.
# [22:15:31] [Match ID 115] Successfully recieved responce 1.
# [22:15:31] [Match ID 115] Trying request attempt 2.
# [22:15:31] [Match ID 115] Successfully recieved responce 2.
# [22:15:31] [Match ID 115] Trying request attempt 3.
# [22:15:31] [Match ID 115] Successfully recieved responce 3.
# [22:15:31] [Match ID 115] Trying request attempt 4.
# [22:15:32] [Match ID 115] Successfully recieved responce 4.
# [22:15:32] [Match ID 115] Trying request attempt 5.
# [22:15:32] [Match ID 115] Successfully recieved responce 5.
#
# [22:15:32] [Match ID 115] model_output_json[115]: ['2', '2', '2', '2', '2']
#
# [22:15:32] [Match ID 116] Starting sentiment analysis for match ~ Stoke City vs Brighton & Hove Albion.
# [22:15:32] [Match ID 116] Trying request attempt 1.
# [22:15:33] [Match ID 116] Successfully recieved responce 1.
# [22:15:33] [Match ID 116] Trying request attempt 2.
# [22:15:36] [Match ID 116] Successfully recieved responce 2.
# [22:15:36] [Match ID 116] Trying request attempt 3.
# [22:15:36] [Match ID 116] Successfully recieved responce 3.
# [22:15:36] [Match ID 116] Trying request attempt 4.
# [22:15:37] [Match ID 116] Successfully recieved responce 4.
# [22:15:37] [Match ID 116] Trying request attempt 5.
# [22:15:37] [Match ID 116] Successfully recieved responce 5.
#
# [22:15:37] [Match ID 116] model_output_json[116]: ['3', '3', '3', '3', '3']
#
# [22:15:37] [Match ID 117] Starting sentiment analysis for match ~ Tottenham Hotspur vs Arsenal.
# [22:15:37] [Match ID 117] Trying request attempt 1.
# [22:15:37] [Match ID 117] Successfully recieved responce 1.
# [22:15:37] [Match ID 117] Trying request attempt 2.
# [22:15:38] [Match ID 117] Successfully recieved responce 2.
# [22:15:38] [Match ID 117] Trying request attempt 3.
# [22:15:38] [Match ID 117] Successfully recieved responce 3.
# [22:15:38] [Match ID 117] Trying request attempt 4.
# [22:15:38] [Match ID 117] Successfully recieved responce 4.
# [22:15:38] [Match ID 117] Trying request attempt 5.
# [22:15:42] [Match ID 117] Successfully recieved responce 5.
#
# [22:15:42] [Match ID 117] model_output_json[117]: ['3', '4', '4', '3', '3']
#
# [22:15:42] [Match ID 118] Starting sentiment analysis for match ~ West Ham United vs Watford.
# [22:15:42] [Match ID 118] Trying request attempt 1.
# [22:15:42] [Match ID 118] Successfully recieved responce 1.
# [22:15:42] [Match ID 118] Trying request attempt 2.
# [22:15:42] [Match ID 118] Successfully recieved responce 2.
# [22:15:42] [Match ID 118] Trying request attempt 3.
# [22:15:42] [Match ID 118] Successfully recieved responce 3.
# [22:15:42] [Match ID 118] Trying request attempt 4.
# [22:15:43] [Match ID 118] Successfully recieved responce 4.
# [22:15:43] [Match ID 118] Trying request attempt 5.
# [22:15:43] [Match ID 118] Successfully recieved responce 5.
#
# [22:15:43] [Match ID 118] model_output_json[118]: ['4', '4', '4', '4', '4']
#
# [22:15:43] [Match ID 119] Starting sentiment analysis for match ~ Everton vs Crystal Palace.
# [22:15:43] [Match ID 119] Trying request attempt 1.
# [22:15:43] [Match ID 119] Successfully recieved responce 1.
# [22:15:43] [Match ID 119] Trying request attempt 2.
# [22:15:44] [Match ID 119] Successfully recieved responce 2.
# [22:15:44] [Match ID 119] Trying request attempt 3.
# [22:15:44] [Match ID 119] Successfully recieved responce 3.
# [22:15:44] [Match ID 119] Trying request attempt 4.
# [22:15:44] [Match ID 119] Successfully recieved responce 4.
# [22:15:44] [Match ID 119] Trying request attempt 5.
# [22:15:45] [Match ID 119] Successfully recieved responce 5.
#
# [22:15:45] [Match ID 119] model_output_json[119]: ['3', '2', '4', '2', '2']
#
# [22:15:45] [Match ID 121] Starting sentiment analysis for match ~ Liverpool vs Tottenham Hotspur.
# [22:15:45] [Match ID 121] Trying request attempt 1.
# ...
# Match 1097 output: ['4', '4', '3', '4', '4']
# Match 1098 output: ['1', '1', '1', '1', '1']
# Match 1100 output: ['4', '4', '4', '4', '4']
# Match 1101 output: ['5', '5', '5', '5', '5']
# Match 1102 output: ['3', '3', '3', '3', '3']
# Match 1103 output: ['4', '4', '4', '4', '4']
# Match 1104 output: ['4', '4', '4', '4', '4']
# Match 1105 output: ['2', '2', '2', '2', '2']
# Match 1106 output: ['2', '2', '2', '2', '2']
# Match 1107 output: ['1', '1', '1', '1', '1']
# Match 1108 output: ['3', '4', '4', '4', '4']
# Match 1109 output: ['2', '2', '2', '3', '2']
# Match 1110 output: ['4', '4', '4', '4', '4']
# Match 1112 output: ['2', '1', '2', '1', '2']
# Match 1113 output: ['5', '5', '5', '5', '5']
# Match 1114 output: ['3', '3', '3', '3', '3']
# Match 1115 output: ['2', '2', '3', '2', '2']
# Match 1117 output: ['2', '1', '2', '2', '2']
# Match 1118 output: ['4', '4', '4', '4', '4']
# Match 1119 output: ['3', '3', '3', '3', '3']
# Match 1120 output: ['4', '4', '4', '4', '4']
# Match 1121 output: ['4', '4', '3', '4', '3']
# Match 1122 output: ['3', '3', '2', '3', '3']
# Match 1123 output: ['3', '3', '3', '3', '3']
# Match 1124 output: ['1', '1', '1', '1', '1']
# Match 1125 output: ['4', '4', '4', '4', '4']
# Match 1126 output: ['3', '3', '3', '3', '3']
# Match 1127 output: ['2', '4', '2', '3', '3']
# Match 1128 output: ['2', '2', '2', '2', '2']
# Match 1129 output: ['2', '2', '2', '2', '2']
# Match 1130 output: ['3', '3', '3', '3', '3']
# Match 1131 output: ['1', '1', '1', '1', '1']
# Match 1132 output: ['5', '5', '5', '5', '5']
# Match 1134 output: ['4', '5', '4', '4', '4']
# Match 1135 output: ['5', '5', '5', '5', '5']
# Match 1136 output: ['3', '3', '3', '3', '3']
# Match 1137 output: ['2', '2', '2', '2', '1']
# Match 1138 output: ['2', '1', '1', '1', '2']
# Match 1139 output: ['4', '4', '4', '4', '4']
# Match 1140 output: ['2', '2', '2', '2', '2']
# Match 1141 output: ['4', '4', '4', '4', '4']
# Match 1142 output: ['4', '4', '4', '4', '4']
# Match 1143 output: ['2', '2', '3', '3', '3']
# Match 1145 output: ['3', '2', '2', '3', '3']
# Match 1146 output: ['4', '4', '4', '4', '4']
# Match 1147 output: ['4', '4', '5', '4', '5']
# Match 1148 output: ['2', '2', '2', '2', '2']
# Match 1149 output: ['2', '2', '2', '2', '3']
# Match 1151 output: ['1', '1', '1', '1', '1']
# Match 1152 output: ['3', '3', '3', '3', '3']
# Match 1153 output: ['4', '4', '4', '4', '4']
# Match 1154 output: ['4', '4', '5', '4', '5']
# Match 1155 output: ['3', '3', '3', '3', '3']
# Match 1156 output: ['2', '2', '2', '2', '2']
# Match 1161 output: ['5', '3', '5', '5', '5']
# Match 1163 output: ['1', '2', '2', '1', '1']
# Match 1164 output: ['4', '4', '4', '4', '4']
# Match 1165 output: ['3', '3', '3', '3', '3']
# Match 1166 output: ['3', '3', '3', '3', '3']
# Match 1167 output: ['3', '3', '3', '3', '3']
# Match 1168 output: ['2', '2', '3', '2', '2']
# Match 1169 output: ['4', '5', '5', '4', '5']
# Match 1170 output: ['3', '4', '3', '3', '4']
# Match 1171 output: ['3', '3', '3', '3', '4']
# Match 1172 output: ['5', '5', '5', '5', '5']
# Match 1173 output: ['3', '3', '3', '3', '3']
# Match 1174 output: ['3', '4', '4', '4', '4']
# Match 1175 output: ['1', '1', '1', '1', '1']
# Match 1176 output: ['4', '4', '4', '4', '4']
# Match 1177 output: ['1', '1', '1', '1', '1']
# Match 1178 output: ['2', '3', '2', '2', '3']
# Match 1180 output: ['1', '1', '1', '1', '1']
# Match 1181 output: ['4', '3', '4', '3', '3']
# Match 1182 output: ['2', '2', '2', '2', '2']
# Match 1183 output: ['3', '4', '4', '4', '3']
# Match 1185 output: ['2', '2', '2', '2', '2']
# Match 1198 output: ['2', '3', '2', '2', '2']
# Match 1199 output: ['2', '2', '2', '2', '3']
# Match 1200 output: ['2', '2', '2', '2', '2']
# Match 1201 output: ['5', '5', '5', '5', '5']
# Match 1202 output: ['3', '3', '3', '3', '3']
# Match 1203 output: ['5', '5', '5', '5', '5']
# Match 1204 output: ['4', '4', '4', '4', '4']
# Match 1205 output: ['3', '3', '3', '3', '3']
# Match 1206 output: ['4', '5', '4', '4', '4']
# Match 1208 output: ['3', '3', '3', '3', '3']
# Match 1209 output: ['2', '3', '3', '3', '3']
# Match 1210 output: ['3', '3', '3', '3', '3']
# Match 1211 output: ['4', '4', '4', '4', '4']
# Match 1212 output: ['5', '5', '5', '5', '5']
# Match 1213 output: ['4', '4', '4', '4', '4']
# Match 1214 output: ['4', '5', '5', '5', '4']
# Match 1216 output: ['2', '3', '2', '2', '2']
# Match 1217 output: ['1', '1', '1', '1', '1']
# Match 1218 output: ['4', '4', '3', '4', '4']
# Match 1220 output: ['4', '4', '4', '4', '4']
# Match 1221 output: ['5', '5', '5', '5', '5']
# Match 1222 output: ['2', '2', '2', '2', '2']
# Match 1223 output: ['3', '3', '3', '3', '3']
# Match 1224 output: ['2', '2', '2', '1', '2']
# Match 1225 output: ['1', '1', '1', '1', '1']
# Match 1226 output: ['4', '4', '4', '4', '4']
# Match 1227 output: ['3', '3', '3', '3', '3']
# Match 1228 output: ['5', '5', '5', '5', '5']
# Match 1229 output: ['1', '1', '1', '1', '1']
# Match 1230 output: ['3', '3', '3', '3', '3']
# Match 1231 output: ['5', '5', '5', '5', '5']
# Match 1232 output: ['2', '2', '2', '2', '2']
# Match 1233 output: ['1', '1', '1', '1', '1']
# Match 1234 output: ['2', '1', '2', '1', '1']
# Match 1236 output: ['4', '4', '4', '4', '5']
# Match 1237 output: ['4', '4', '4', '4', '4']
# Match 1238 output: ['5', '4', '5', '4', '5']
# Match 1240 output: ['4', '4', '4', '3', '3']
# Match 1241 output: ['2', '2', '2', '2', '2']
# Match 1242 output: ['3', '4', '3', '4', '4']
# Match 1243 output: ['3', '3', '3', '3', '3']
# Match 1244 output: ['1', '1', '1', '1', '1']
# Match 1245 output: ['4', '4', '4', '4', '4']
# Match 1246 output: ['3', '3', '2', '3', '3']
# Match 1247 output: ['3', '3', '4', '3', '3']
# Match 1248 output: ['5', '5', '5', '5', '5']
# Match 1249 output: ['3', '3', '3', '3', '4']
# Match 1251 output: ['3', '3', '3', '3', '3']
# Match 1252 output: ['2', '4', '2', '1', '1']
# Match 1253 output: ['3', '3', '3', '3', '3']
# Match 1254 output: ['1', '1', '1', '1', '1']
# Match 1255 output: ['3', '3', '3', '3', '3']
# Match 1256 output: ['4', '5', '5', '5', '4']
# Match 1257 output: ['3', '3', '3', '2', '3']
# Match 1258 output: ['4', '4', '4', '4', '4']
# Match 1259 output: ['4', '4', '4', '4', '4']
# Match 1260 output: ['3', '3', '3', '3', '3']
# Match 1261 output: ['3', '3', '3', '3', '3']
# Match 1263 output: ['1', '1', '1', '1', '1']
# Match 1264 output: ['1', '1', '1', '1', '1']
# Match 1265 output: ['2', '2', '3', '2', '2']
# Match 1266 output: ['2', '2', '2', '2', '2']
# Match 1267 output: ['5', '5', '5', '5', '5']
# Match 1268 output: ['1', '1', '1', '1', '1']
# Match 1269 output: ['3', '3', '2', '2', '2']
# Match 1270 output: ['4', '5', '5', '5', '5']
# Match 1271 output: ['2', '2', '2', '3', '2']
# Match 1272 output: ['3', '3', '3', '3', '3']
# Match 1273 output: ['1', '1', '1', '1', '1']
# Match 1274 output: ['2', '2', '2', '2', '2']
# Match 1276 output: ['2', '2', '2', '2', '2']
# Match 1278 output: ['4', '4', '4', '3', '3']
# Match 1279 output: ['5', '5', '4', '4', '4']
# Match 1280 output: ['3', '3', '3', '3', '3']
# Match 1281 output: ['5', '5', '5', '5', '5']
# Match 1282 output: ['4', '4', '4', '4', '4']
# Match 1283 output: ['1', '1', '1', '1', '1']
# Match 1284 output: ['3', '3', '3', '3', '3']
# Match 1285 output: ['2', '2', '2', '2', '2']
# Match 1286 output: ['4', '4', '4', '4', '4']
# Match 1287 output: ['1', '1', '1', '1', '1']
# Match 1288 output: ['3', '2', '4', '3', '3']
# Match 1289 output: ['3', '3', '4', '4', '3']
# Match 1290 output: ['4', '4', '4', '4', '4']
# Match 1291 output: ['5', '4', '5', '5', '5']
# Match 1292 output: ['5', '5', '1', '5', '5']
# Match 1293 output: ['3', '3', '3', '3', '3']
# Match 1294 output: ['4', '4', '4', '4', '4']
# Match 1295 output: ['3', '3', '3', '3', '3']
# Match 1296 output: ['3', '3', '1', '4', '4']
# Match 1297 output: ['2', '3', '3', '3', '3']
# Match 1298 output: ['4', '4', '4', '4', '4']
# Match 1299 output: ['4', '4', '4', '4', '4']
# Match 1300 output: ['5', '5', '5', '5', '5']
# Match 1301 output: ['2', '3', '2', '2', '2']
# Match 1302 output: ['1', '1', '1', '1', '1']
# Match 1303 output: ['3', '3', '3', '3', '3']
# Match 1305 output: ['3', '4', '3', '3', '4']
# Match 1306 output: ['4', '4', '4', '4', '4']
# Match 1308 output: ['3', '3', '3', '3', '3']
# Match 1309 output: ['2', '2', '2', '2', '2']
# Match 1310 output: ['2', '2', '2', '2', '2']
# Match 1311 output: ['5', '5', '5', '5', '5']
# Match 1312 output: ['3', '2', '3', '3', '3']
# Match 1313 output: ['4', '4', '4', '4', '4']
# Match 1314 output: ['3', '3', '4', '3', '4']
# Match 1315 output: ['3', '3', '3', '3', '3']
# Match 1316 output: ['4', '4', '4', '3', '3']
# Match 1317 output: ['5', '5', '5', '5', '5']
# Match 1318 output: ['3', '2', '2', '2', '2']
# Match 1319 output: ['4', '2', '2', '4', '2']
# Match 1320 output: ['3', '3', '3', '3', '3']
# Match 1321 output: ['3', '3', '3', '2', '2']
# Match 1323 output: ['1', '1', '1', '1', '1']
# Match 1324 output: ['4', '4', '3', '4', '3']
# Match 1325 output: ['3', '3', '3', '3', '3']
# Match 1326 output: ['1', '1', '1', '1', '1']
# Match 1327 output: ['4', '3', '4', '4', '4']
# Match 1328 output: ['2', '3', '2', '2', '2']
# Match 1329 output: ['5', '5', '5', '5', '5']
# Match 1330 output: ['2', '2', '2', '2', '2']
# Match 1331 output: ['4', '5', '5', '5', '5']
# Match 1332 output: ['4', '4', '4', '3', '4']
# Match 1334 output: ['2', '2', '3', '3', '2']
# Match 1335 output: ['4', '4', '4', '4', '4']
# Match 1337 output: ['1', '1', '1', '1', '1']
# Match 1338 output: ['4', '4', '4', '5', '5']
# Match 1339 output: ['3', '2', '2', '1', '2']
# Match 1340 output: ['3', '3', '3', '3', '3']
# Match 1341 output: ['1', '1', '1', '1', '1']
# Match 1342 output: ['3', '4', '3', '3', '4']
# Match 1343 output: ['3', '3', '4', '4', '3']
# Match 1344 output: ['1', '1', '1', '1', '1']
# Match 1345 output: ['4', '4', '4', '3', '3']
# Match 1346 output: ['2', '2', '2', '2', '2']
# Match 1347 output: ['3', '3', '3', '3', '4']
# Match 1348 output: ['1', '1', '2', '2', '2']
# Match 1349 output: ['4', '4', '4', '4', '4']
# Match 1350 output: ['4', '4', '4', '4', '4']
# Match 1351 output: ['3', '3', '4', '4', '3']
# Match 1352 output: ['4', '4', '4', '4', '4']
# Match 1354 output: ['2', '2', '2', '3', '2']
# Match 1355 output: ['4', '4', '4', '4', '4']
# Match 1356 output: ['2', '2', '2', '1', '2']
# Match 1357 output: ['1', '1', '1', '1', '1']
# Match 1358 output: ['2', '3', '3', '3', '3']
# Match 1359 output: ['3', '3', '3', '2', '3']
# Match 1361 output: ['3', '3', '2', '3', '2']
# Match 1362 output: ['4', '4', '4', '4', '4']
# Match 1363 output: ['2', '2', '2', '2', '2']
# Match 1364 output: ['3', '2', '3', '3', '2']
# Match 1365 output: ['4', '3', '4', '3', '3']
# Match 1366 output: ['4', '4', '4', '4', '4']
# Match 1367 output: ['3', '3', '2', '2', '3']
# Match 1368 output: ['2', '2', '2', '2', '2']
# Match 1369 output: ['4', '4', '4', '5', '4']
# Match 1370 output: ['4', '4', '4', '4', '4']
# Match 1371 output: ['3', '3', '3', '3', '3']
# Match 1372 output: ['4', '4', '4', '4', '3']
# Match 1373 output: ['3', '2', '2', '3', '3']
# Match 1375 output: ['4', '5', '5', '4', '5']
# Match 1377 output: ['1', '1', '1', '1', '2']
# Match 1378 output: ['1', '1', '1', '1', '1']
# Match 1379 output: ['3', '3', '3', '3', '3']
# Match 1380 output: ['1', '2', '2', '1', '2']
# Match 1381 output: ['2', '2', '2', '2', '2']
# Match 1382 output: ['5', '4', '4', '5', '4']
# Match 1383 output: ['5', '5', '5', '5', '5']
# Match 1384 output: ['3', '3', '3', '3', '3']
# Match 1385 output: ['3', '3', '3', '3', '3']
# Match 1386 output: ['1', '1', '1', '1', '1']
# Match 1387 output: ['3', '3', '3', '3', '3']
# Match 1388 output: ['2', '2', '3', '3', '3']
# Match 1389 output: ['5', '5', '5', '5', '5']
# Match 1390 output: ['2', '2', '1', '2', '2']
# Match 1391 output: ['4', '4', '2', '3', '3']
# Match 1393 output: ['2', '4', '3', '3', '3']
# Match 1394 output: ['2', '2', '2', '2', '3']
# Match 1395 output: ['5', '5', '5', '5', '5']
# Match 1396 output: ['1', '1', '1', '1', '1']
# Match 1397 output: ['5', '5', '5', '5', '5']
# Match 1398 output: ['4', '3', '3', '3', '3']
# Match 1399 output: ['3', '3', '3', '2', '3']
# Match 1400 output: ['3', '3', '3', '3', '3']
# Match 1401 output: ['5', '5', '5', '5', '5']
# Match 1402 output: ['3', '3', '3', '3', '3']
# Match 1403 output: ['3', '3', '3', '3', '3']
# Match 1405 output: ['2', '2', '2', '2', '2']
# Match 1406 output: ['3', '3', '3', '3', '3']
# Match 1407 output: ['1', '2', '2', '2', '1']
# Match 1408 output: ['4', '4', '4', '4', '4']
# Match 1409 output: ['3', '3', '3', '3', '4']
# Match 1410 output: ['5', '5', '5', '5', '5']
# Match 1412 output: ['3', '3', '3', '3', '3']
# Match 1413 output: ['3', '3', '3', '3', '3']
# Match 1414 output: ['2', '2', '2', '2', '2']
# Match 1415 output: ['4', '2', '3', '2', '4']
# Match 1416 output: ['3', '3', '3', '3', '3']
# Match 1417 output: ['1', '1', '1', '1', '2']
# Match 1418 output: ['4', '4', '4', '4', '4']
# Match 1419 output: ['5', '4', '4', '5', '5']
# Match 1420 output: ['2', '2', '2', '2', '2']
# Match 1422 output: ['5', '4', '4', '5', '5']
# Match 1423 output: ['2', '2', '2', '2', '2']
# Match 1424 output: ['2', '2', '2', '2', '2']
# Match 1426 output: ['2', '2', '2', '2', '2']
# Match 1427 output: ['5', '4', '4', '4', '4']
# Match 1428 output: ['3', '3', '3', '3', '3']
# Match 1429 output: ['2', '2', '3', '2', '3']
# Match 1430 output: ['4', '4', '4', '4', '4']
# Match 1431 output: ['3', '3', '3', '3', '3']
# Match 1432 output: ['4', '4', '4', '4', '4']
# Match 1433 output: ['5', '5', '5', '5', '5']
# Match 1434 output: ['4', '5', '5', '5', '5']
# Match 1435 output: ['5', '5', '5', '5', '5']
# Match 1436 output: ['2', '2', '2', '3', '3']
# Match 1438 output: ['4', '4', '4', '4', '4']
# Match 1439 output: ['5', '1', '1', '1', '1']
# Match 1440 output: ['5', '5', '5', '5', '5']
# Match 1441 output: ['3', '3', '3', '4', '4']
# Match 1444 output: ['2', '2', '2', '2', '3']
# Match 1446 output: ['3', '3', '3', '3', '3']
# Match 1447 output: ['2', '2', '2', '2', '2']
# Match 1448 output: ['3', '4', '4', '4', '4']
# Match 1449 output: ['2', '2', '2', '2', '2']
# Match 1450 output: ['2', '2', '2', '2', '5']
# Match 1451 output: ['2', '3', '3', '3', '3']
# Match 1452 output: ['4', '4', '4', '4', '4']
# Match 1453 output: ['1', '2', '1', '1', '2']
# Match 1454 output: ['4', '4', '4', '4', '4']
# Match 1455 output: ['5', '5', '5', '5', '4']
# Match 1456 output: ['1', '1', '1', '1', '1']
# Match 1457 output: ['3', '3', '3', '3', '3']
# Match 1458 output: ['5', '5', '5', '5', '5']
# Match 1459 output: ['3', '4', '3', '4', '3']
# Match 1460 output: ['5', '5', '5', '5', '5']
# Match 1461 output: ['1', '1', '1', '1', '1']
# Match 1462 output: ['5', '5', '5', '5', '5']
# Match 1464 output: ['1', '1', '1', '1', '1']
# Match 1465 output: ['3', '3', '3', '2', '2']
# Match 1466 output: ['3', '3', '3', '3', '3']
# Match 1468 output: ['4', '4', '4', '4', '4']
# Match 1469 output: ['1', '1', '1', '1', '1']
# Match 1470 output: ['3', '4', '4', '4', '4']
# Match 1471 output: ['4', '3', '3', '3', '3']
# Match 1472 output: ['5', '5', '5', '5', '5']
# Match 1473 output: ['1', '1', '1', '1', '1']
# Match 1474 output: ['5', '4', '5', '5', '4']
# Match 1475 output: ['3', '4', '3', '2', '4']
# Match 1476 output: ['5', '5', '5', '5', '5']
# Match 1477 output: ['4', '4', '3', '3', '3']
# Match 1478 output: ['1', '1', '1', '1', '1']
# Match 1479 output: ['5', '5', '5', '5', '5']
# Match 1480 output: ['3', '3', '3', '3', '2']
# Match 1481 output: ['3', '3', '3', '3', '3']
# Match 1482 output: ['3', '3', '3', '3', '3']
# Match 1485 output: ['1', '1', '1', '1', '1']
# Match 1486 output: ['2', '2', '2', '2', '1']
# Match 1487 output: ['5', '4', '4', '5', '5']
# Match 1488 output: ['4', '5', '4', '4', '4']
# Match 1489 output: ['2', '2', '2', '3', '3']
# Match 1491 output: ['2', '3', '3', '3', '3']
# Match 1492 output: ['2', '2', '3', '3', '3']
# Match 1493 output: ['3', '3', '3', '4', '3']
# Match 1494 output: ['5', '5', '5', '4', '5']
# Match 1495 output: ['3', '3', '4', '4', '4']
# Match 1496 output: ['3', '3', '3', '3', '3']
# Match 1497 output: ['3', '3', '3', '3', '3']
# Match 1498 output: ['5', '5', '5', '4', '4']
# Match 1499 output: ['4', '4', '4', '4', '4']
# Match 1501 output: ['3', '3', '3', '3', '4']
# Match 1502 output: ['4', '4', '4', '5', '4']
# Match 1504 output: ['2', '2', '2', '2', '2']
# Match 1505 output: ['3', '3', '2', '3', '3']
# Match 1506 output: ['2', '2', '2', '2', '2']
# Match 1507 output: ['2', '3', '3', '2', '2']
# Match 1508 output: ['2', '2', '2', '2', '2']
# Match 1509 output: ['2', '2', '2', '2', '2']
# Match 1510 output: ['1', '1', '1', '1', '1']

# %% [markdown]
# #### Gemini

# %%
import google.generativeai as genai

# %%
gemini_api_key_dir = f"../../../API Keys/gemini.txt"
with open(gemini_api_key_dir) as f:
    lines = f.readlines()
    gemini_api_key = lines[0].strip()

# %%
genai.configure(api_key=gemini_api_key)
model_gemini_15_flash = genai.GenerativeModel("gemini-1.5-flash")

# %%
model_output = {}

# Test model consistency
for match_idx in range(100):
    match_idx_str = str(match_idx)

    if match_idx_str not in model_output:
        model_output[match_idx_str] = []
    
    while len(model_output[match_idx_str]) < 5:
        try:
            print(f"[{time.strftime('%H:%M:%S')}] Trying request for match {match_idx}.")
            prompt = create_prompt(match_idx, version=2)
            response = model_gemini_15_flash.generate_content(prompt)
            print(f"[{time.strftime('%H:%M:%S')}] Successfully responce for match {match_idx}.")
            model_output[match_idx_str].append(response.text.strip())
        except Exception as e:
            print(f"[{time.strftime('%H:%M:%S')}] Error: {e}")
            if "429" in str(e):
                print(f"[{time.strftime('%H:%M:%S')}] Pausing new requests for 1 minute.")
                time.sleep(60)
            elif "504" in str(e):
                print(f"[{time.strftime('%H:%M:%S')}] Skipping {match_idx}.")

    print(f"[{time.strftime('%H:%M:%S')}] Match {match_idx} output: {model_output[match_idx_str]}")

print("\nFINAL RESULTS:")
for match in model_output:
    print(f"Match {match} output: {model_output[match]}")
