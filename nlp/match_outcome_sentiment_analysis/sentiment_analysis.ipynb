# %%
import pandas as pd
import time
import json
import textwrap

# %%
df = pd.read_csv('../../datasets/processed/Combined_Dataset.csv')
print(df.head())
# Out:
#    MatchID               Home                    Away  \
# 0        0       Swansea City              Stoke City
# 1        2  Tottenham Hotspur          Leicester City
# 2        3          Liverpool  Brighton & Hove Albion
# 3        4            Burnley         AFC Bournemouth
# 4        5        Southampton         Manchester City
#
#                         Date   Season  \
# 0  Fri 11 May 2018 17.23 BST  2017-18
# 1  Fri 11 May 2018 16.43 BST  2017-18
# 2  Fri 11 May 2018 16.33 BST  2017-18
# 3  Fri 11 May 2018 16.23 BST  2017-18
# 4  Fri 11 May 2018 16.07 BST  2017-18
#
#                                                 Text              DateTime  \
# 0  A match many thought would have so much riding...  2018-05-13T00:00:00Z
# 1  Leicester’s 3-1 win over Arsenal on Wednesday ...  2018-05-13T00:00:00Z
# 2  Complaints over Liverpool’s recent league form...  2018-05-13T00:00:00Z
# 3  Burnley are looking for their first win in fiv...  2018-05-13T00:00:00Z
# 4  Manchester City’s quest for 100 points come up...  2018-05-13T00:00:00Z
#
#    FTHG  FTAG FTR  ...   HST  AST   HC    AC    HF    AF   HY   AY   HR   AR
# 0   1.0   2.0   A  ...  11.0  5.0  6.0   0.0  12.0   9.0  1.0  2.0  0.0  0.0
# 1   5.0   4.0   H  ...   6.0  9.0  4.0   4.0   9.0  13.0  1.0  2.0  0.0  0.0
# 2   4.0   0.0   H  ...  11.0  1.0  7.0   3.0   3.0   6.0  0.0  0.0  0.0  0.0
# 3   1.0   2.0   A  ...   4.0  5.0  7.0   8.0  14.0   9.0  0.0  0.0  0.0  0.0
# 4   0.0   1.0   A  ...   3.0  2.0  1.0  12.0   8.0  10.0  3.0  1.0  0.0  0.0
#
# [5 rows x 26 columns]

# %%
def get_match_info(match_df_idx):
    return {
        "Match_ID": df.iloc[match_df_idx]['MatchID'],
        "Home": df.iloc[match_df_idx]['Home'],
        "Away": df.iloc[match_df_idx]['Away'],
        "Preview": df.iloc[match_df_idx]['Text'],
        "Season": df.iloc[match_df_idx]['Season'],
    }

# %%
def get_time():
    return time.strftime('%H:%M:%S')

# %% [markdown]
# ### Prompts

# %%
def create_prompt(match_df_idx, version=1):

    match_info = get_match_info(match_df_idx)
    home = match_info['Home']
    away = match_info['Away']
    preview = match_info['Preview']
    
    prompt = ""

    if version == 1:
        prompt += "You are tasked with reading a preview for a football match and determining based on the preview which team is being favored to win."
        prompt += f"Respond with the number based on the following scale that best matches the sentiment of the preview."
        prompt += f"If the home team is strongly favored to win, respond with 1."
        prompt += f"If the home team is slightly favored to win, respond with 2."
        prompt += f"If the match is balanced with no clear favor, respond with 3."
        prompt += f"If the away team is slightly favored to win, respond with 4."
        prompt += f"If the away team is strongly favored to win, respond with 5."
        prompt += f"The home team is {home} and the away team is {away}."
        prompt += f"The preview is: {preview}"

    elif version == 2:
        prompt += f"Is the home team {home} or the away team {away} favored to win the match based on the preview? "
        prompt += f"Use the underlying sentiment of the preview and understanding of football language and context. "
        prompt += f"If the home team {home} is strongly favored, respond '1'. "
        prompt += f"If the home team {home} is slightly favored, respond '2'. "
        prompt += f"If the match is balanced with no clear favorite, respond '3'. "
        prompt += f"If the away team {away} is slightly favored, respond '4'. "
        prompt += f"If the away team {away} is strongly favored, respond '5'. "
        prompt += f"Match preview: {preview}"
    
    elif version == 3:
        prompt += f"You are tasked with identifying if the home team {home} or the away team {away} is favored to win based on the match preview. "
        prompt += f"Do not use any historical performances or statistics to make your decision. "
        prompt += f"Just analyze the underlying sentiment of the preview and use understanding of football language and context. "
        prompt += f"If the home team {home} is strongly favored, respond '1'. "
        prompt += f"If the home team {home} is slightly favored, respond '2'. "
        prompt += f"If the match is balanced with no clear favorite, respond '3'. "
        prompt += f"If the away team {away} is slightly favored, respond '4'. "
        prompt += f"If the away team {away} is strongly favored, respond '5'. "
        prompt += f"Only respond with the number based on the scale that best matches the sentiment of the preview. "
        prompt += f"Although you should understand why you chose that number, you don't need to explain why. "
        prompt += f"Match preview: {preview}"
    
    return prompt

# %% [markdown]
# ### OpenAI

# %%
from openai import OpenAI

# %%
openai_api_key_dir = f"../../../API Keys/openai.txt"
with open(openai_api_key_dir) as f:
    lines = f.readlines()
    openai_api_key = lines[0].strip()

# %%
client = OpenAI(api_key=openai_api_key)

# %%
def get_openai_response(prompt, model="gpt-4o-mini", preliminary_content_version=1):

    if preliminary_content_version == 1:
        preliminary_content = "You are an AI assistant that analyzes and classifies sentiment in match previews for predicting match outcomes for the Premier League."
    else:
        preliminary_content = "You are an AI assistant that analyzes and classifies sentiment in match previews for predicting match outcomes for the Premier League."

    completion = client.chat.completions.create(
        model=model,
        messages=[
            {"role": "system", "content": preliminary_content},
            {"role": "user", "content": prompt}
        ]
    )

    return completion.choices[0].message.content

# %%
NUM_MODEL_SAMPLES = 5
MAX_ALLOWED_ATTEMPTS = 8

# Initialize model output json
model_output_dir = f"output/sentiment-analysis_gpt-4o-mini_prompt-v3.json"
model_output_json = json.load(open(model_output_dir))

# Loop through each match
for match_df_idx in range(30):

    # Get match information
    match_info = get_match_info(match_df_idx)
    match_id = match_info['Match_ID']
    match_id_str = str(match_id)
    home = match_info['Home']
    away = match_info['Away']
    season = match_info['Season']
    print(f"[{get_time()}] [Match ID {match_id}] Starting sentiment analysis for match ~ {home} vs {away}.")
    
    # Add match to model output json
    if match_id_str not in model_output_json:
        model_output_json[match_id_str] = []
    
    # Loop to get 5 responses
    attempts = 0
    while len(model_output_json[match_id_str]) < NUM_MODEL_SAMPLES:

        # Break early if too many attempts
        attempts += 1
        if attempts > MAX_ALLOWED_ATTEMPTS:
            print(f"[{get_time()}] [Match ID {match_id}] Max attempts ({attempts-1}) reached.")
            break

        # Get model output
        try:
            print(f"[{get_time()}] [Match ID {match_id}] Trying request attempt {attempts}.")
            prompt = create_prompt(match_df_idx, version=3)
            output = get_openai_response(prompt)
            output = output.strip()

            if len(output) > 1:
                print(f"[{get_time()}] [Match ID {match_id}] Issue with model output, longer than 1 character. ~ Output:\n{textwrap.fill(output, width=100)}")
                continue

            elif not(any(char in output for char in '12345')):
                print(f"[{get_time()}] [Match ID {match_id}] Issue with model output, No classification found in output. ~ Output:\n{textwrap.fill(output, width=100)}")
                continue

            # Add output to model output json
            model_output_json[match_id_str].append(output)
            with open(model_output_dir, 'w') as f:
                json.dump(model_output_json, f, indent=4)
            print(f"[{get_time()}] [Match ID {match_id}] Successfully recieved responce {len(model_output_json[match_id_str])}.")
        
        except Exception as e:
            print(f"[{get_time()}] [Match ID {match_id}] Error getting model output: {e}")
            
            # if "429" in str(e):
            #     print(f"[{get_time()}] [Match ID {match_id}] Pausing new requests for 1 minute.")
            #     time.sleep(60)

    print(f"\n[{get_time()}] [Match ID {match_id}] model_output_json[{match_id}]: {model_output_json[match_id_str]}\n")

print("\nFINAL RESULTS:")
for match_id_str in model_output_json:
    print(f"Match {match_id_str} output: {model_output_json[match_id_str]}")
# Out:
# [00:33:01] [Match ID 0] Starting sentiment analysis for match ~ Swansea City vs Stoke City.
# [00:33:01] [Match ID 0] Trying request attempt 1.
# [00:33:02] [Match ID 0] Successfully recieved responce 3.
# [00:33:02] [Match ID 0] Trying request attempt 2.
# [00:33:02] [Match ID 0] Successfully recieved responce 4.
# [00:33:02] [Match ID 0] Trying request attempt 3.
# [00:33:02] [Match ID 0] Successfully recieved responce 5.
#
# [00:33:02] [Match ID 0] model_output_json[0]: ['3', '3', '3', '3', '3']
#
# [00:33:02] [Match ID 2] Starting sentiment analysis for match ~ Tottenham Hotspur vs Leicester City.
# [00:33:02] [Match ID 2] Trying request attempt 1.
# [00:33:02] [Match ID 2] Successfully recieved responce 3.
# [00:33:02] [Match ID 2] Trying request attempt 2.
# [00:33:03] [Match ID 2] Successfully recieved responce 4.
# [00:33:03] [Match ID 2] Trying request attempt 3.
# [00:33:03] [Match ID 2] Successfully recieved responce 5.
#
# [00:33:03] [Match ID 2] model_output_json[2]: ['3', '3', '3', '2', '3']
#
# [00:33:03] [Match ID 3] Starting sentiment analysis for match ~ Liverpool vs Brighton & Hove Albion.
# [00:33:03] [Match ID 3] Trying request attempt 1.
# [00:33:04] [Match ID 3] Successfully recieved responce 3.
# [00:33:04] [Match ID 3] Trying request attempt 2.
# [00:33:04] [Match ID 3] Successfully recieved responce 4.
# [00:33:04] [Match ID 3] Trying request attempt 3.
# [00:33:04] [Match ID 3] Successfully recieved responce 5.
#
# [00:33:04] [Match ID 3] model_output_json[3]: ['1', '1', '1', '2', '2']
#
# [00:33:04] [Match ID 4] Starting sentiment analysis for match ~ Burnley vs AFC Bournemouth.
# [00:33:04] [Match ID 4] Trying request attempt 1.
# [00:33:04] [Match ID 4] Successfully recieved responce 3.
# [00:33:04] [Match ID 4] Trying request attempt 2.
# [00:33:05] [Match ID 4] Successfully recieved responce 4.
# [00:33:05] [Match ID 4] Trying request attempt 3.
# [00:33:05] [Match ID 4] Successfully recieved responce 5.
#
# [00:33:05] [Match ID 4] model_output_json[4]: ['3', '3', '3', '3', '3']
#
# [00:33:05] [Match ID 5] Starting sentiment analysis for match ~ Southampton vs Manchester City.
# [00:33:05] [Match ID 5] Trying request attempt 1.
# [00:33:05] [Match ID 5] Successfully recieved responce 3.
# [00:33:05] [Match ID 5] Trying request attempt 2.
# [00:33:05] [Match ID 5] Successfully recieved responce 4.
# [00:33:05] [Match ID 5] Trying request attempt 3.
# [00:33:06] [Match ID 5] Successfully recieved responce 5.
#
# [00:33:06] [Match ID 5] model_output_json[5]: ['5', '5', '5', '5', '5']
#
# [00:33:06] [Match ID 6] Starting sentiment analysis for match ~ Manchester United vs Watford.
# [00:33:06] [Match ID 6] Trying request attempt 1.
# [00:33:06] [Match ID 6] Successfully recieved responce 3.
# [00:33:06] [Match ID 6] Trying request attempt 2.
# [00:33:06] [Match ID 6] Successfully recieved responce 4.
# [00:33:06] [Match ID 6] Trying request attempt 3.
# [00:33:07] [Match ID 6] Successfully recieved responce 5.
#
# [00:33:07] [Match ID 6] model_output_json[6]: ['3', '3', '3', '3', '3']
#
# [00:33:07] [Match ID 7] Starting sentiment analysis for match ~ Crystal Palace vs West Bromwich Albion.
# [00:33:07] [Match ID 7] Trying request attempt 1.
# [00:33:07] [Match ID 7] Successfully recieved responce 3.
# [00:33:07] [Match ID 7] Trying request attempt 2.
# [00:33:07] [Match ID 7] Successfully recieved responce 4.
# [00:33:07] [Match ID 7] Trying request attempt 3.
# [00:33:08] [Match ID 7] Successfully recieved responce 5.
#
# [00:33:08] [Match ID 7] model_output_json[7]: ['3', '3', '3', '3', '3']
#
# [00:33:08] [Match ID 8] Starting sentiment analysis for match ~ West Ham United vs Everton.
# [00:33:08] [Match ID 8] Trying request attempt 1.
# [00:33:08] [Match ID 8] Successfully recieved responce 3.
# [00:33:08] [Match ID 8] Trying request attempt 2.
# [00:33:08] [Match ID 8] Successfully recieved responce 4.
# [00:33:08] [Match ID 8] Trying request attempt 3.
# [00:33:09] [Match ID 8] Successfully recieved responce 5.
#
# [00:33:09] [Match ID 8] model_output_json[8]: ['3', '3', '3', '3', '3']
#
# [00:33:09] [Match ID 9] Starting sentiment analysis for match ~ Arsenal vs Burnley.
# [00:33:09] [Match ID 9] Trying request attempt 1.
# [00:33:09] [Match ID 9] Successfully recieved responce 3.
# [00:33:09] [Match ID 9] Trying request attempt 2.
# [00:33:09] [Match ID 9] Successfully recieved responce 4.
# [00:33:09] [Match ID 9] Trying request attempt 3.
# [00:33:09] [Match ID 9] Successfully recieved responce 5.
#
# [00:33:09] [Match ID 9] model_output_json[9]: ['1', '2', '2', '2', '1']
#
# [00:33:09] [Match ID 10] Starting sentiment analysis for match ~ Chelsea vs Liverpool.
# [00:33:09] [Match ID 10] Trying request attempt 1.
# [00:33:10] [Match ID 10] Successfully recieved responce 3.
# [00:33:10] [Match ID 10] Trying request attempt 2.
# [00:33:10] [Match ID 10] Successfully recieved responce 4.
# [00:33:10] [Match ID 10] Trying request attempt 3.
# [00:33:10] [Match ID 10] Successfully recieved responce 5.
#
# [00:33:10] [Match ID 10] model_output_json[10]: ['3', '3', '3', '3', '3']
#
# [00:33:10] [Match ID 11] Starting sentiment analysis for match ~ Manchester City vs Huddersfield Town.
# [00:33:10] [Match ID 11] Trying request attempt 1.
# [00:33:11] [Match ID 11] Successfully recieved responce 1.
# [00:33:11] [Match ID 11] Trying request attempt 2.
# [00:33:11] [Match ID 11] Successfully recieved responce 2.
# [00:33:11] [Match ID 11] Trying request attempt 3.
# [00:33:12] [Match ID 11] Successfully recieved responce 3.
# [00:33:12] [Match ID 11] Trying request attempt 4.
# [00:33:12] [Match ID 11] Successfully recieved responce 4.
# [00:33:12] [Match ID 11] Trying request attempt 5.
# [00:33:13] [Match ID 11] Successfully recieved responce 5.
#
# [00:33:13] [Match ID 11] model_output_json[11]: ['1', '1', '1', '1', '1']
#
# [00:33:13] [Match ID 12] Starting sentiment analysis for match ~ Stoke City vs Crystal Palace.
# [00:33:13] [Match ID 12] Trying request attempt 1.
# [00:33:13] [Match ID 12] Successfully recieved responce 1.
# [00:33:13] [Match ID 12] Trying request attempt 2.
# [00:33:13] [Match ID 12] Successfully recieved responce 2.
# [00:33:13] [Match ID 12] Trying request attempt 3.
# [00:33:14] [Match ID 12] Successfully recieved responce 3.
# [00:33:14] [Match ID 12] Trying request attempt 4.
# [00:33:14] [Match ID 12] Successfully recieved responce 4.
# [00:33:14] [Match ID 12] Trying request attempt 5.
# [00:33:14] [Match ID 12] Successfully recieved responce 5.
#
# [00:33:14] [Match ID 12] model_output_json[12]: ['4', '4', '4', '4', '4']
#
# [00:33:14] [Match ID 13] Starting sentiment analysis for match ~ West Bromwich Albion vs Tottenham Hotspur.
# [00:33:14] [Match ID 13] Trying request attempt 1.
# [00:33:15] [Match ID 13] Successfully recieved responce 1.
# [00:33:15] [Match ID 13] Trying request attempt 2.
# [00:33:15] [Match ID 13] Successfully recieved responce 2.
# [00:33:15] [Match ID 13] Trying request attempt 3.
# [00:33:15] [Match ID 13] Successfully recieved responce 3.
# [00:33:15] [Match ID 13] Trying request attempt 4.
# [00:33:15] [Match ID 13] Successfully recieved responce 4.
# [00:33:15] [Match ID 13] Trying request attempt 5.
# [00:33:16] [Match ID 13] Successfully recieved responce 5.
#
# [00:33:16] [Match ID 13] model_output_json[13]: ['5', '5', '5', '5', '5']
#
# [00:33:16] [Match ID 15] Starting sentiment analysis for match ~ Leicester City vs West Ham United.
# [00:33:16] [Match ID 15] Trying request attempt 1.
# [00:33:16] [Match ID 15] Successfully recieved responce 1.
# [00:33:16] [Match ID 15] Trying request attempt 2.
# [00:33:17] [Match ID 15] Successfully recieved responce 2.
# [00:33:17] [Match ID 15] Trying request attempt 3.
# [00:33:17] [Match ID 15] Successfully recieved responce 3.
# [00:33:17] [Match ID 15] Trying request attempt 4.
# [00:33:17] [Match ID 15] Successfully recieved responce 4.
# [00:33:17] [Match ID 15] Trying request attempt 5.
# [00:33:18] [Match ID 15] Successfully recieved responce 5.
#
# [00:33:18] [Match ID 15] model_output_json[15]: ['5', '5', '5', '5', '5']
#
# [00:33:18] [Match ID 16] Starting sentiment analysis for match ~ AFC Bournemouth vs Swansea City.
# [00:33:18] [Match ID 16] Trying request attempt 1.
# [00:33:18] [Match ID 16] Successfully recieved responce 1.
# [00:33:18] [Match ID 16] Trying request attempt 2.
# [00:33:19] [Match ID 16] Successfully recieved responce 2.
# [00:33:19] [Match ID 16] Trying request attempt 3.
# [00:33:19] [Match ID 16] Successfully recieved responce 3.
# [00:33:19] [Match ID 16] Trying request attempt 4.
# [00:33:20] [Match ID 16] Successfully recieved responce 4.
# [00:33:20] [Match ID 16] Trying request attempt 5.
# [00:33:20] [Match ID 16] Successfully recieved responce 5.
#
# [00:33:20] [Match ID 16] model_output_json[16]: ['1', '1', '1', '1', '1']
#
# [00:33:20] [Match ID 17] Starting sentiment analysis for match ~ Everton vs Southampton.
# [00:33:20] [Match ID 17] Trying request attempt 1.
# [00:33:20] [Match ID 17] Successfully recieved responce 1.
# [00:33:20] [Match ID 17] Trying request attempt 2.
# [00:33:21] [Match ID 17] Successfully recieved responce 2.
# [00:33:21] [Match ID 17] Trying request attempt 3.
# [00:33:21] [Match ID 17] Successfully recieved responce 3.
# [00:33:21] [Match ID 17] Trying request attempt 4.
# [00:33:22] [Match ID 17] Successfully recieved responce 4.
# [00:33:22] [Match ID 17] Trying request attempt 5.
# [00:33:22] [Match ID 17] Successfully recieved responce 5.
#
# [00:33:22] [Match ID 17] model_output_json[17]: ['3', '3', '3', '3', '3']
#
# [00:33:22] [Match ID 18] Starting sentiment analysis for match ~ Tottenham Hotspur vs Watford.
# [00:33:22] [Match ID 18] Trying request attempt 1.
# [00:33:22] [Match ID 18] Successfully recieved responce 1.
# [00:33:22] [Match ID 18] Trying request attempt 2.
# [00:33:23] [Match ID 18] Successfully recieved responce 2.
# [00:33:23] [Match ID 18] Trying request attempt 3.
# [00:33:23] [Match ID 18] Successfully recieved responce 3.
# [00:33:23] [Match ID 18] Trying request attempt 4.
# [00:33:23] [Match ID 18] Successfully recieved responce 4.
# [00:33:23] [Match ID 18] Trying request attempt 5.
# [00:33:23] [Match ID 18] Successfully recieved responce 5.
#
# [00:33:23] [Match ID 18] model_output_json[18]: ['1', '2', '1', '2', '1']
#
# [00:33:23] [Match ID 19] Starting sentiment analysis for match ~ West Ham United vs Manchester City.
# [00:33:23] [Match ID 19] Trying request attempt 1.
# [00:33:24] [Match ID 19] Successfully recieved responce 1.
# [00:33:24] [Match ID 19] Trying request attempt 2.
# [00:33:24] [Match ID 19] Successfully recieved responce 2.
# [00:33:24] [Match ID 19] Trying request attempt 3.
# [00:33:24] [Match ID 19] Successfully recieved responce 3.
# [00:33:24] [Match ID 19] Trying request attempt 4.
# [00:33:24] [Match ID 19] Successfully recieved responce 4.
# [00:33:24] [Match ID 19] Trying request attempt 5.
# [00:33:25] [Match ID 19] Successfully recieved responce 5.
#
# [00:33:25] [Match ID 19] model_output_json[19]: ['5', '5', '5', '5', '5']
#
# [00:33:25] [Match ID 20] Starting sentiment analysis for match ~ Manchester United vs Arsenal.
# [00:33:25] [Match ID 20] Trying request attempt 1.
# [00:33:25] [Match ID 20] Successfully recieved responce 1.
# [00:33:25] [Match ID 20] Trying request attempt 2.
# [00:33:25] [Match ID 20] Successfully recieved responce 2.
# [00:33:25] [Match ID 20] Trying request attempt 3.
# [00:33:25] [Match ID 20] Successfully recieved responce 3.
# [00:33:25] [Match ID 20] Trying request attempt 4.
# [00:33:26] [Match ID 20] Successfully recieved responce 4.
# [00:33:26] [Match ID 20] Trying request attempt 5.
# [00:33:26] [Match ID 20] Successfully recieved responce 5.
#
# [00:33:26] [Match ID 20] model_output_json[20]: ['3', '3', '3', '3', '3']
#
# [00:33:26] [Match ID 21] Starting sentiment analysis for match ~ Burnley vs Brighton & Hove Albion.
# [00:33:26] [Match ID 21] Trying request attempt 1.
# [00:33:26] [Match ID 21] Successfully recieved responce 1.
# [00:33:26] [Match ID 21] Trying request attempt 2.
# [00:33:27] [Match ID 21] Successfully recieved responce 2.
# [00:33:27] [Match ID 21] Trying request attempt 3.
# [00:33:27] [Match ID 21] Successfully recieved responce 3.
# [00:33:27] [Match ID 21] Trying request attempt 4.
# [00:33:27] [Match ID 21] Successfully recieved responce 4.
# [00:33:27] [Match ID 21] Trying request attempt 5.
# [00:33:28] [Match ID 21] Successfully recieved responce 5.
#
# [00:33:28] [Match ID 21] model_output_json[21]: ['2', '2', '2', '2', '2']
#
# [00:33:28] [Match ID 23] Starting sentiment analysis for match ~ Swansea City vs Chelsea.
# [00:33:28] [Match ID 23] Trying request attempt 1.
# [00:33:28] [Match ID 23] Successfully recieved responce 1.
# [00:33:28] [Match ID 23] Trying request attempt 2.
# [00:33:28] [Match ID 23] Successfully recieved responce 2.
# [00:33:28] [Match ID 23] Trying request attempt 3.
# [00:33:29] [Match ID 23] Successfully recieved responce 3.
# [00:33:29] [Match ID 23] Trying request attempt 4.
# [00:33:29] [Match ID 23] Successfully recieved responce 4.
# [00:33:29] [Match ID 23] Trying request attempt 5.
# [00:33:29] [Match ID 23] Successfully recieved responce 5.
#
# [00:33:29] [Match ID 23] model_output_json[23]: ['4', '4', '4', '4', '4']
#
# [00:33:29] [Match ID 24] Starting sentiment analysis for match ~ Crystal Palace vs Leicester City.
# [00:33:29] [Match ID 24] Trying request attempt 1.
# [00:33:30] [Match ID 24] Successfully recieved responce 1.
# [00:33:30] [Match ID 24] Trying request attempt 2.
# [00:33:30] [Match ID 24] Successfully recieved responce 2.
# [00:33:30] [Match ID 24] Trying request attempt 3.
# [00:33:30] [Match ID 24] Successfully recieved responce 3.
# [00:33:30] [Match ID 24] Trying request attempt 4.
# [00:33:31] [Match ID 24] Successfully recieved responce 4.
# [00:33:31] [Match ID 24] Trying request attempt 5.
# [00:33:31] [Match ID 24] Successfully recieved responce 5.
#
# [00:33:31] [Match ID 24] model_output_json[24]: ['2', '1', '2', '2', '2']
#
# [00:33:31] [Match ID 25] Starting sentiment analysis for match ~ Huddersfield Town vs Everton.
# [00:33:31] [Match ID 25] Trying request attempt 1.
# [00:33:31] [Match ID 25] Successfully recieved responce 1.
# [00:33:31] [Match ID 25] Trying request attempt 2.
# [00:33:32] [Match ID 25] Successfully recieved responce 2.
# [00:33:32] [Match ID 25] Trying request attempt 3.
# [00:33:32] [Match ID 25] Successfully recieved responce 3.
# [00:33:32] [Match ID 25] Trying request attempt 4.
# [00:33:32] [Match ID 25] Successfully recieved responce 4.
# [00:33:32] [Match ID 25] Trying request attempt 5.
# [00:33:33] [Match ID 25] Successfully recieved responce 5.
#
# [00:33:33] [Match ID 25] model_output_json[25]: ['5', '5', '4', '5', '5']
#
# [00:33:33] [Match ID 26] Starting sentiment analysis for match ~ Southampton vs AFC Bournemouth.
# [00:33:33] [Match ID 26] Trying request attempt 1.
# [00:33:33] [Match ID 26] Successfully recieved responce 1.
# [00:33:33] [Match ID 26] Trying request attempt 2.
# [00:33:33] [Match ID 26] Successfully recieved responce 2.
# [00:33:33] [Match ID 26] Trying request attempt 3.
# [00:33:34] [Match ID 26] Successfully recieved responce 3.
# [00:33:34] [Match ID 26] Trying request attempt 4.
# [00:33:34] [Match ID 26] Successfully recieved responce 4.
# [00:33:34] [Match ID 26] Trying request attempt 5.
# [00:33:35] [Match ID 26] Successfully recieved responce 5.
#
# [00:33:35] [Match ID 26] model_output_json[26]: ['3', '3', '3', '4', '3']
#
# [00:33:35] [Match ID 27] Starting sentiment analysis for match ~ Liverpool vs Stoke City.
# [00:33:35] [Match ID 27] Trying request attempt 1.
# [00:33:35] [Match ID 27] Successfully recieved responce 1.
# [00:33:35] [Match ID 27] Trying request attempt 2.
# [00:33:36] [Match ID 27] Successfully recieved responce 2.
# [00:33:36] [Match ID 27] Trying request attempt 3.
# [00:33:36] [Match ID 27] Successfully recieved responce 3.
# [00:33:36] [Match ID 27] Trying request attempt 4.
# [00:33:37] [Match ID 27] Successfully recieved responce 4.
# [00:33:37] [Match ID 27] Trying request attempt 5.
# [00:33:37] [Match ID 27] Successfully recieved responce 5.
#
# [00:33:37] [Match ID 27] model_output_json[27]: ['1', '1', '1', '1', '1']
#
# [00:33:37] [Match ID 28] Starting sentiment analysis for match ~ Everton vs Newcastle.
# [00:33:37] [Match ID 28] Trying request attempt 1.
# [00:33:37] [Match ID 28] Successfully recieved responce 1.
# [00:33:37] [Match ID 28] Trying request attempt 2.
# [00:33:38] [Match ID 28] Successfully recieved responce 2.
# [00:33:38] [Match ID 28] Trying request attempt 3.
# [00:33:38] [Match ID 28] Successfully recieved responce 3.
# [00:33:38] [Match ID 28] Trying request attempt 4.
# [00:33:38] [Match ID 28] Successfully recieved responce 4.
# [00:33:38] [Match ID 28] Trying request attempt 5.
# [00:33:38] [Match ID 28] Successfully recieved responce 5.
#
# [00:33:38] [Match ID 28] model_output_json[28]: ['5', '5', '5', '5', '5']
#
# [00:33:38] [Match ID 29] Starting sentiment analysis for match ~ Arsenal vs West Ham United.
# [00:33:38] [Match ID 29] Trying request attempt 1.
# [00:33:39] [Match ID 29] Successfully recieved responce 1.
# [00:33:39] [Match ID 29] Trying request attempt 2.
# [00:33:39] [Match ID 29] Successfully recieved responce 2.
# [00:33:39] [Match ID 29] Trying request attempt 3.
# [00:33:39] [Match ID 29] Successfully recieved responce 3.
# [00:33:39] [Match ID 29] Trying request attempt 4.
# [00:33:40] [Match ID 29] Successfully recieved responce 4.
# [00:33:40] [Match ID 29] Trying request attempt 5.
# [00:33:40] [Match ID 29] Successfully recieved responce 5.
#
# [00:33:40] [Match ID 29] model_output_json[29]: ['3', '3', '2', '3', '3']
#
# [00:33:40] [Match ID 30] Starting sentiment analysis for match ~ Chelsea vs Southampton.
# [00:33:40] [Match ID 30] Trying request attempt 1.
# [00:33:40] [Match ID 30] Successfully recieved responce 1.
# [00:33:40] [Match ID 30] Trying request attempt 2.
# [00:33:40] [Match ID 30] Successfully recieved responce 2.
# [00:33:40] [Match ID 30] Trying request attempt 3.
# [00:33:41] [Match ID 30] Successfully recieved responce 3.
# [00:33:41] [Match ID 30] Trying request attempt 4.
# [00:33:41] [Match ID 30] Successfully recieved responce 4.
# [00:33:41] [Match ID 30] Trying request attempt 5.
# [00:33:41] [Match ID 30] Successfully recieved responce 5.
#
# [00:33:41] [Match ID 30] model_output_json[30]: ['1', '1', '1', '1', '1']
#
# [00:33:41] [Match ID 31] Starting sentiment analysis for match ~ Manchester City vs Swansea City.
# [00:33:41] [Match ID 31] Trying request attempt 1.
# [00:33:41] [Match ID 31] Successfully recieved responce 1.
# [00:33:41] [Match ID 31] Trying request attempt 2.
# [00:33:42] [Match ID 31] Successfully recieved responce 2.
# [00:33:42] [Match ID 31] Trying request attempt 3.
# [00:33:42] [Match ID 31] Successfully recieved responce 3.
# [00:33:42] [Match ID 31] Trying request attempt 4.
# [00:33:42] [Match ID 31] Successfully recieved responce 4.
# [00:33:42] [Match ID 31] Trying request attempt 5.
# [00:33:43] [Match ID 31] Successfully recieved responce 5.
#
# [00:33:43] [Match ID 31] model_output_json[31]: ['1', '1', '1', '1', '1']
#
# [00:33:43] [Match ID 32] Starting sentiment analysis for match ~ Stoke City vs Burnley.
# [00:33:43] [Match ID 32] Trying request attempt 1.
# [00:33:43] [Match ID 32] Successfully recieved responce 1.
# [00:33:43] [Match ID 32] Trying request attempt 2.
# [00:33:43] [Match ID 32] Successfully recieved responce 2.
# [00:33:43] [Match ID 32] Trying request attempt 3.
# [00:33:44] [Match ID 32] Successfully recieved responce 3.
# [00:33:44] [Match ID 32] Trying request attempt 4.
# [00:33:44] [Match ID 32] Successfully recieved responce 4.
# [00:33:44] [Match ID 32] Trying request attempt 5.
# [00:33:44] [Match ID 32] Successfully recieved responce 5.
#
# [00:33:44] [Match ID 32] model_output_json[32]: ['4', '3', '4', '4', '3']
#
#
# FINAL RESULTS:
# Match 0 output: ['3', '3', '3', '3', '3']
# Match 2 output: ['3', '3', '3', '2', '3']
# Match 3 output: ['1', '1', '1', '2', '2']
# Match 4 output: ['3', '3', '3', '3', '3']
# Match 5 output: ['5', '5', '5', '5', '5']
# Match 6 output: ['3', '3', '3', '3', '3']
# Match 7 output: ['3', '3', '3', '3', '3']
# Match 8 output: ['3', '3', '3', '3', '3']
# Match 9 output: ['1', '2', '2', '2', '1']
# Match 10 output: ['3', '3', '3', '3', '3']
# Match 11 output: ['1', '1', '1', '1', '1']
# Match 12 output: ['4', '4', '4', '4', '4']
# Match 13 output: ['5', '5', '5', '5', '5']
# Match 15 output: ['5', '5', '5', '5', '5']
# Match 16 output: ['1', '1', '1', '1', '1']
# Match 17 output: ['3', '3', '3', '3', '3']
# Match 18 output: ['1', '2', '1', '2', '1']
# Match 19 output: ['5', '5', '5', '5', '5']
# Match 20 output: ['3', '3', '3', '3', '3']
# Match 21 output: ['2', '2', '2', '2', '2']
# Match 23 output: ['4', '4', '4', '4', '4']
# Match 24 output: ['2', '1', '2', '2', '2']
# Match 25 output: ['5', '5', '4', '5', '5']
# Match 26 output: ['3', '3', '3', '4', '3']
# Match 27 output: ['1', '1', '1', '1', '1']
# Match 28 output: ['5', '5', '5', '5', '5']
# Match 29 output: ['3', '3', '2', '3', '3']
# Match 30 output: ['1', '1', '1', '1', '1']
# Match 31 output: ['1', '1', '1', '1', '1']
# Match 32 output: ['4', '3', '4', '4', '3']

# %% [markdown]
# ### Gemini

# %%
import google.generativeai as genai

# %%
gemini_api_key_dir = f"../../../API Keys/gemini.txt"
with open(gemini_api_key_dir) as f:
    lines = f.readlines()
    gemini_api_key = lines[0].strip()

# %%
genai.configure(api_key=gemini_api_key)
model_gemini_15_flash = genai.GenerativeModel("gemini-1.5-flash")

# %%
# model_output = {
#     '0': ['3', '3', '3', '3', '3'],
#     '1': ['2', '2', '2', '2', '2'],
#     '2': ['2', '2', '2', '2', '1'],
#     '3': ['3', '3', '2', '2', '2'],
#     '4': ['5', '5', '5', '5', '5'],
#     '5': ['2', '4', '4', '4', '2']
# }

# # Test model consistency
# for match_idx in range(100):
#     match_idx_str = str(match_idx)

#     if match_idx_str not in model_output:
#         model_output[match_idx_str] = []
    
#     while len(model_output[match_idx_str]) < 5:
#         try:
#             print(f"[{time.strftime('%H:%M:%S')}] Trying request for match {match_idx}.")
#             prompt = create_prompt(match_idx, version=2)
#             response = model_gemini_15_flash.generate_content(prompt)
#             print(f"[{time.strftime('%H:%M:%S')}] Successfully responce for match {match_idx}.")
#             model_output[match_idx_str].append(response.text.strip())
#         except Exception as e:
#             print(f"[{time.strftime('%H:%M:%S')}] Error: {e}")
#             if "429" in str(e):
#                 print(f"[{time.strftime('%H:%M:%S')}] Pausing new requests for 1 minute.")
#                 time.sleep(60)
#             elif "504" in str(e):
#                 print(f"[{time.strftime('%H:%M:%S')}] Skipping {match_idx}.")

#     print(f"[{time.strftime('%H:%M:%S')}] Match {match_idx} output: {model_output[match_idx_str]}")

# print("\nFINAL RESULTS:")
# for match in model_output:
#     print(f"Match {match} output: {model_output[match]}")

# %%
# import concurrent.futures
# import threading
# import time

# model_output = {
#     '0': ['3', '3', '3', '3', '3'],
#     '1': ['2', '2', '2', '2', '2'],
#     '2': ['2', '2', '2', '2', '1'],
#     '3': ['3', '3', '2', '2', '2'],
#     '4': ['5', '5', '5', '5', '5'],
#     '5': ['2', '4', '4', '4', '2']
# }

# pause_event = threading.Event()
# pause_event.set()

# def fetch_responses(match_idx):
#     if match_idx not in model_output:
#         model_output[match_idx] = []
#     while len(model_output[match_idx]) < 5:
#         try:
#             pause_event.wait()
#             prompt = create_prompt(match_idx, version=2)
#             print(f"[{time.strftime('%H:%M:%S')}] Getting model response for match {match_idx}...")
#             response = model_gemini_15_flash.generate_content(prompt)
#             print(f"[{time.strftime('%H:%M:%S')}] Successfully recieved model response for match {match_idx}...")
#             model_output[match_idx].append(response.text.strip())
#         except Exception as e:
#             print(f"[{time.strftime('%H:%M:%S')}] Error: {e}")
#             if "429" in str(e):
#                 print(f"[{time.strftime('%H:%M:%S')}] Pausing new requests for 2 minutes.")
#                 pause_event.clear()
#                 time.sleep(120)
#                 pause_event.set()

# with concurrent.futures.ThreadPoolExecutor() as executor:
#     match_indices = range(8)
#     executor.map(fetch_responses, match_indices)

# for match_idx in model_output:
#     print(f"Match {match_idx} output: {model_output[match_idx]}")

# %%
# regions = [“europe-west4”, “us-east1”, “europe-north1”, “europe-west1”, “europe-west2”, “europe-west3”, “europe-west6”, “europe-central2”]
# random.shuffle(regions)
# gemini_models = [“gemini-1.5-flash-002”,“gemini-1.5-flash-002”, “gemini-1.5-pro-002”]
# random.shuffle(gemini_models)
# selected_region = regions[0]
# selected_model = gemini_models[0]
